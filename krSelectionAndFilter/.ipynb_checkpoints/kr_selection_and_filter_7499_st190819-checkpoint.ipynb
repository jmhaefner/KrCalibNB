# %% [markdown]
# # Selection of krypton events in terms of S1 and S2

# %% [markdown]
# ## Authors: JMH, JAH, GML, JJGC

# %% [markdown]
# ### Software: KrCalib : https://github.com/nextic/KrCalib/

# %% [markdown]
# ### Description:
#
# - run = 7499

# %%
import time
print("Last updated on ", time.asctime())
# Out:
# Last updated on  Mon Sep  2 12:12:46 2019

# %%
run_number  = 7499
file_range  = 0, 2172 
num_files = 2172
tags        = '20190801_autotrigger'
analysis_tag = 'st190819'

# Just for testing
# run_number  = 7376
# file_range  = 0, 8798 
# num_files = 8798
# tags        = 'v0.9.9_20190111_krbg'
# analysis_tag = 'st190819'

if num_files > 7729:
    num_xy_bins = 100
else:
    num_xy_bins = 50

t0 = time.time()
last_time = t0

input_path  = f"$IC_DATA/kdst"
output_path = f"$IC_DATA/"+analysis_tag+"/dst"
log_path    = f"$IC_DATA/"+analysis_tag+"/log"
trigger     = 'trigger1'
summary_outputs = "/Users/jmhaefner/Development/KryptonCalibration/KrCalibNB_JMH/KrCalibNB/doc/img/r"+str(run_number)+analysis_tag+"/"

bootstrap_correction_filename   = f"$IC_DATA/maps/kr_corrections_run6165.h5"
write_filtered_dst = True

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = 10, 8
plt.rcParams["font.size"     ] = 14

# %%
import os
import time
import datetime 
import numpy as np
import pandas as pd
import tables            as tb
import random
import glob
import seaborn as sns
sns.set()

# %%
from  invisible_cities.io.dst_io              import load_dsts
from  invisible_cities.core .core_functions   import in_range
from  invisible_cities.core.system_of_units_c import units

# %%
from krcal.core.io_functions       import filenames_from_paths
from krcal.core.io_functions       import write_monitor_vars
from krcal.core.io_functions       import kdst_write
from krcal.core.histo_functions    import h1, h1d, h2d, plot_histo

# %%
from krcal.core.kr_types           import PlotLabels
from krcal.core.ranges_and_bins_functions      import kr_ranges_and_bins
from krcal.core.analysis_functions import kr_event
from krcal.core.analysis_functions import selection_info
from krcal.core.analysis_functions import selection_in_band
from krcal.core.analysis_functions import plot_selection_in_band
from krcal.core.s1s2_functions     import s1d_from_dst
from krcal.core.s1s2_functions     import s2d_from_dst
from krcal.core.s1s2_functions     import plot_s1histos
from krcal.core.s1s2_functions     import plot_s2histos

# %%
from krcal.core.plt_functions      import plot_xy_density
from krcal.core.plt_functions      import plot_s1_vs_z
from krcal.core.plt_functions      import plot_s2_vs_z
from krcal.core.plt_functions      import plot_s2_vs_s1
from krcal.core.plt_functions      import plot_q_vs_s2
from krcal.core.plt_functions      import plot_energy_distributions
from krcal.core.plt_functions      import plot_energy_vs_t

# %%
import krcal.dev.corrections       as corrections 
import krcal.utils.hst_extend_functions as hst

# %%
from krcal.core.core_functions          import time_delta_from_time

# %% [markdown]
# ### Create vals file

# %%
# vals
import subprocess

# %%
# vals
vals_dir_loc = '/Users/jmhaefner/Development/KryptonCalibration/KrCalibNB_JMH/KrCalibNB/doc/data_'+str(run_number)+analysis_tag+'/'
bash_mkdir = "mkdir " + vals_dir_loc
process = subprocess.Popen(bash_mkdir, stdout=subprocess.PIPE, shell=True).wait()

# %%
# vals
vals_loc = vals_dir_loc + 'vals_'+str(run_number)+'.txt'
bash_touch = "touch " + vals_loc
process = subprocess.Popen(bash_touch, stdout=subprocess.PIPE, shell=True).wait()

# %%
# vals
summary_vals = open(vals_loc, 'w') # start by erasing the old file, then just append in later use.
summary_vals.write('runNumber='+str(run_number)+'\n')
summary_vals.write('lastFile='+str(file_range[1])+'\n')
summary_vals.close()

# %% [markdown]
# ### Input/output

# %%
input_dst_filenames, output_dst_filename, log_filename = filenames_from_paths(run_number,
                                                                              input_path,
                                                                              output_path,
                                                                              log_path,
                                                                              trigger,
                                                                              tags,
                                                                              file_range)
                                                                              
print(f'input dsts:\n first = {input_dst_filenames[0]}\n last = {input_dst_filenames[-1]}')
print(f"output dst = {output_dst_filename}")
print(f"log file   = {log_filename}")           

print('time before dst load =', round(time.time() - last_time))
last_time = time.time()
# Out:
# input dsts:
#  first = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0000_7499_trigger1_20190801_autotrigger.h5
#  last = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_2171_7499_trigger1_20190801_autotrigger.h5
# output dst = /Volumes/NEXT_data/IC_Data//st190819/dst/dst_7499_trigger1_0000_2171.h5
# log file   = /Volumes/NEXT_data/IC_Data//st190819/log/log_7499_trigger1_0000_2171.h5
# time before dst load = 9

# %%
dst_full           = load_dsts(input_dst_filenames, "DST", "Events")
print('time to load dst =', round(time.time() - last_time))
last_time = time.time()
# Out:
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0000_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0001_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0002_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0003_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0004_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0005_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0006_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0007_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0008_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0009_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0010_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0011_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0012_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0013_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0014_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0015_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0016_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0017_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0018_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0019_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0020_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0021_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0022_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0023_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0024_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0025_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0026_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0027_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0028_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0029_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0030_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0031_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0032_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0033_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0034_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0035_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0036_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0037_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0038_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0039_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0040_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0041_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0042_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0043_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0044_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0045_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0046_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0047_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0048_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0049_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0050_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0051_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0052_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0053_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0054_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0055_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0056_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0057_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0058_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0059_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0060_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0061_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0062_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0063_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0064_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0065_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0066_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0067_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0068_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0069_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0070_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0071_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0072_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0073_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0074_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0075_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0076_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0077_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0078_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0079_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0080_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0081_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0082_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0083_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0084_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0085_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0086_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0087_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0088_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0089_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0090_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0091_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0092_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0093_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0094_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0095_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0096_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0097_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0098_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0099_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0100_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0101_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0102_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0103_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0104_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0105_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0106_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0107_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0108_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0109_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0110_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0111_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0112_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0113_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0114_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0115_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0116_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0117_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0118_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0119_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0120_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0121_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0122_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0123_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0124_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0125_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0126_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0127_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0128_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0129_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0130_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0131_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0132_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0133_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0134_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0135_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0136_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0137_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0138_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0139_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0140_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0141_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0142_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0143_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0144_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0145_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0146_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0147_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0148_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0149_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0150_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0151_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0152_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0153_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0154_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0155_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0156_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0157_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0158_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0159_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0160_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0161_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0162_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0163_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0164_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0165_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0166_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0167_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0168_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0169_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0170_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0171_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# ...
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_2121_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_2122_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_2123_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_2124_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_2125_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_2126_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_2127_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_2128_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_2129_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_2130_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_2131_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_2132_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_2133_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_2134_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_2135_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_2136_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_2137_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_2138_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_2139_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_2140_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_2141_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_2142_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_2143_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_2144_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_2145_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_2146_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_2147_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_2148_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_2149_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_2150_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_2151_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_2152_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_2153_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_2154_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_2155_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_2156_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_2157_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_2158_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_2159_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_2160_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_2161_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_2162_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_2163_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_2164_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_2165_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_2166_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_2167_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_2168_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_2169_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_2170_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7499/kdst_2171_7499_trigger1_20190801_autotrigger.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-16c036eda77c> in <module>
# ----> 1 dst_full           = load_dsts(input_dst_filenames, "DST", "Events")
#       2 print('time to load dst =', round(time.time() - last_time))
#       3 last_time = time.time()
#
# ~/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py in load_dsts(dst_list, group, node)
#      24 def load_dsts(dst_list, group, node):
#      25     dsts = [load_dst(filename, group, node) for filename in dst_list]
# ---> 26     return pd.concat(dsts)
#
# ~/miniconda/envs/IC-3.7-2018-11-14/lib/python3.7/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     223                        keys=keys, levels=levels, names=names,
#     224                        verify_integrity=verify_integrity,
# --> 225                        copy=copy, sort=sort)
#     226     return op.get_result()
#     227
#
# ~/miniconda/envs/IC-3.7-2018-11-14/lib/python3.7/site-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     275
#     276         if len(objs) == 0:
# --> 277             raise ValueError('All objects passed were None')
#     278
#     279         # consolidate data & figure out what our result ndim is going to be
#
# ValueError: All objects passed were None

# %%
input_dst_filenames[0]
# Out:
# '/Volumes/NEXT_data/IC_Data//kdst/7499/kdst_0000_7499_trigger1_20190801_autotrigger.h5'

# %%
unique_events = ~dst_full.event.duplicated()

number_of_S2s_full  = np.size         (unique_events)
number_of_evts_full = np.count_nonzero(unique_events)

print(f"Total number of S2s   : {number_of_S2s_full} ")
print(f"Total number of events: {number_of_evts_full}")

# vals
summary_vals = open(vals_loc, 'a')
summary_vals.write(f'totalNumS2={number_of_S2s_full}\n')
summary_vals.write(f'totalNumEvt={number_of_evts_full}\n')
summary_vals.close()

# %%
dst_full.columns

# %%
ntot = len(dst_full)
print(f"length of dst = {ntot}")

# %% [markdown]
# ### S1/S2

# %%
n, b, _, _ = h1d(dst_full.nS1.values, bins = 10, range = (0,10),
           pltLabels=PlotLabels(x='nS1', y='Entries', title='nS1'))

# %%
fnS1 = n[n.argmax()]/np.sum(n)
print(f'fraction of S1s = {fnS1}')

# %% [markdown]
# #### Fraction of events with 1 S1 is 0.5, due to grass and high energy events. For Krypton select events with 1 S1

# %% [markdown]
# ### Select events with 1 S1

# %%
dst1s1 = dst_full[dst_full.nS1==1]

# %%
n, b, _, _ = h1d(dst1s1.nS2.values, bins = 10, range = (0,10),
           pltLabels=PlotLabels(x='nS2', y='Entries', title='nS2'))

# %% [markdown]
# #### For Krypton select events with only 1 S2

# %%
fnS2 = n[n.argmax()]/np.sum(n)
print(f'fraction of S2s = {fnS2}')

# %% [markdown]
# ### Select events with 1 S2

# %%
dst    = dst1s1[dst1s1.nS2==1]

# %%
n_full   = len(dst)
eff = n_full   / ntot 
print(f"Total number of events with 1 s1 and 1 s2 : {n_full}: selection eff = {eff} ")

# vals
summary_vals = open(vals_loc, 'a')
summary_vals.write(f'fracS1={round(fnS1,2)}\n')
summary_vals.write(f'fracS2={round(fnS2,2)}\n')
summary_vals.write(f'fracS1S2={round(eff,2)}\n')
summary_vals.close()

# %% [markdown]
# ### S1 and S2 distributions

# %%
s1d = s1d_from_dst(dst)

# %%
bash_mkdir = "mkdir " + summary_outputs
process = subprocess.Popen(bash_mkdir, stdout=subprocess.PIPE, shell=True).wait()

# %%
plot_s1histos(dst,  s1d, bins=20, figsize=(10,10))
plt.savefig(summary_outputs+'s1.png')

# %% [markdown]
# ### Fiducial selection in S1

# %% [markdown]
# #### 2 < S1e < 25 pes, which cuts off very low and high energy events

# %%
s1e_range =(3, 25)

# vals
summary_vals = open(vals_loc, 'a')
summary_vals.write(f's1Min={s1e_range[0]}\n')
summary_vals.write(f's1Max={s1e_range[1]}\n')
summary_vals.close()

# %%
dst_s1e    = dst[in_range(dst.S1e, *s1e_range)]

# %%
s1d = s1d_from_dst(dst_s1e, range_s1e = s1e_range)
plot_s1histos(dst_s1e,  s1d, bins=20, figsize=(10,10))

# %%
dst = dst_s1e
s2d = s2d_from_dst(dst)
plot_s2histos(dst, s2d, bins=20, emin=1000, emax=15000, figsize=(10,10))
plt.savefig(summary_outputs+'s2.png')

# %% [markdown]
# ### Fiducial selection in S2

# %%
Nsipm_min = 15 
s2e_range =(3000, 13000)
s2w_range =(5, 15)
s2q_range =(200, 800)

# vals
summary_vals = open(vals_loc, 'a')
summary_vals.write(f's2MinPMT={s2e_range[0]}\n')
summary_vals.write(f's2MaxPMT={s2e_range[1]}\n')
summary_vals.write(f's2MinQ={s2q_range[0]}\n')
summary_vals.write(f's2MaxQ={s2q_range[1]}\n')
summary_vals.write(f'widthMin={s2w_range[0]}\n')
summary_vals.write(f'widthMax={s2w_range[1]}\n')
summary_vals.write(f'numSipmMin={Nsipm_min}\n')
summary_vals.close()

# %%
dst_sipm    = dst[dst.Nsipm >Nsipm_min] 
dst_s2e    = dst_sipm[in_range(dst_sipm.S2e, *s2e_range)] 
dst_s2w    = dst_s2e[in_range(dst_s2e.S2w, *s2w_range)]
dst_s2q    = dst_s2w[in_range(dst_s2w.S2q, *s2q_range)]
dst = dst_s2q

# %%
s2d = s2d_from_dst(dst_s2e)
plot_s2histos(dst, s2d, bins=20, emin=1000, emax=15000, figsize=(10,10))

# %% [markdown]
# ### Time differences in seconds

# %%
dst_time = dst.sort_values('event')
T       = dst_time.time.values
DT      = time_delta_from_time(T)

# %% [markdown]
# ### Define ranges and bins

# %%
krTimes, krRanges, krNbins, krBins = kr_ranges_and_bins(dst,
                                                        xxrange   = (-220,  220),
                                                        yrange    = (-220,  220),
                                                        zrange    = (10,  550),
                                                        s2erange  = s2e_range,
                                                        s1erange  = s1e_range,
                                                        s2qrange  = s2q_range,
                                                        xnbins    = num_xy_bins,
                                                        ynbins    = num_xy_bins,
                                                        znbins    = 50,
                                                        s2enbins  = 50,
                                                        s1enbins  = 50,
                                                        s2qnbins  = 50,
                                                        tpsamples = 3600) # tsamples in seconds

# %% [markdown]
# ### Time
# - Extension in hours of data sample considered

# %%
plt.plot(krTimes.timeStamps)
plt.savefig(summary_outputs+'runTime.png')

# %%
# vals
full_final_datetime = str(krTimes.timeStamps[-1])
final_date = full_final_datetime[:full_final_datetime.find(' ')]

# Once you have the date, find the temperature on that date.
import codecs

ctrl = 'SNS'

def itemize(line):
    items = []
    while len(line) > 0:
        if not line.find('\t') == -1:
            potential_item = line[:line.find('\t')]
            potential_item = potential_item.strip()
            if not potential_item == "":
                items.append(potential_item)
            line = line[line.find('\t')+1:]
        elif line.find('\n') == -1:
            items.append(line)
            line = ""
        else:
            line = ""
    return items

vessel_temps = []
param_of_interest = "NEW"

text_path = "/Users/jmhaefner/Dropbox/Data/" + ctrl + "_Data_Report_" + final_date + ".txt"

if os.path.isfile(text_path):
    data_file = codecs.open(text_path, 'r', encoding='ISO-8859-1')
    data_lines = data_file.readlines()

    parameters = itemize(data_lines[2])
    first_data = itemize(data_lines[3])

    for i in range(len(parameters)):
        try:
            print_params = parameters[i]+'='+first_data[i]
            #print(print_params)
        except:
            # print('Failed to find a value for param', [parameters[i]])
            parameters.pop(i)
            i -= 1

    for i in range(len(parameters)):
        for j in range(3,len(data_lines)):
            if parameters[i] == param_of_interest:
                itemized = itemize(data_lines[j])
                value = float(itemized[i].replace(',', '.'))
                vessel_temps.append(value)

    day_temp = sum(vessel_temps)/(1.0 * len(vessel_temps))
    print('The day temp on '+final_date+' was '+str(round(day_temp,1)))
else:
    day_temp = 'nan'
    print('UNABLE TO FIND TEMPERATURE FILE '+text_path)

summary_vals = open(vals_loc, 'a')
summary_vals.write('date='+final_date+'\n')
if day_temp != 'nan':
    summary_vals.write('labTempC='+str(round(day_temp,1))+'\n')
else:
    summary_vals.write('labTempC='+day_temp)
summary_vals.close()

# %%
kge = kr_event(dst, DT, dst.S2e, dst.S2q)

# %%
fig = plt.figure(figsize=(10,6))
ax      = fig.add_subplot(1, 1, 1)
(_)    = h1(kge.DT, bins=500, range = (kge.DT[0], kge.DT[-1]), color='red', stats=False, lbl='pre-sel')
plt.savefig(summary_outputs+'runEvt.png')

# %% [markdown]
# ### Control distributions

# %%
nevt = h2d(dst.X, dst.Y, krNbins.X, krNbins.Y, krRanges.X, krRanges.Y, 
           pltLabels=PlotLabels(x='X (mm)', y='Y (mm)', title='X vs Y'),
           profile=False,
           figsize=(10,8))
plt.savefig(summary_outputs+'xy.png')

# %%
nevt = h2d(dst.Z, dst.S1e, krNbins.Z, krNbins.S1e, krRanges.Z, (0,20), 
           pltLabels=PlotLabels(x='Z (mm)', y='S1e (pes)', title='S1 vs Z'),
           profile=False,
           figsize=(10,8))

# %% [markdown]
# #### S1 vs Z distribution:
#
# - Concentrated at low Z: This is due to the fact that gas flow is higher near the anode, and thus there is more krypton near the anode than near the cathode.
# - Increases as a function of Z. The closer to the cathode the larger S1
# - Spread is large: This is due to large variation of solid angle, depending on (X,Y)

# %%
nevt = h2d(dst.Z, dst.S2e, krNbins.Z, krNbins.S1e, krRanges.Z, krRanges.S2e, 
           pltLabels=PlotLabels(x='Z (mm)', y='S2e (pes)', title='S2 vs Z'),
           profile=True,
           figsize=(10,8))

# %% [markdown]
# #### S2 vs Z distribution:
#
# - Concentrated at low Z: This is due to the fact that gas flow is higher near the anode, and thus there is more krypton near the anode than near the cathode.
# - Decreases as a function of Z, due to lifetime
# - Spread is large: This is due to large variation of solid angle, depending on (X,Y)

# %%
nevt = h2d(dst.S1e, dst.S2e, krNbins.S1e, krNbins.S2e, krRanges.S1e, krRanges.S2e, 
           pltLabels=PlotLabels(x='S1e (pes)', y='S2e (pes)', title='S2 vs S1'),
           profile=False,
           figsize=(10,8))

# %% [markdown]
# #### S2 vs S1 distribution:
#
# - Small anti-correlation (more S2 less S1).

# %%
nevt = h2d(dst.S2e, dst.S2q, krNbins.S2e, krNbins.S2q, krRanges.S2e, krRanges.S2q, 
           pltLabels=PlotLabels(x='S2e (pes)', y='S2q (pes)', title='S2e vs S2q'),
           profile=False,
           figsize=(10,8))

# %% [markdown]
# #### S2 vs Q distribution:
#
# - Clear correlation between S2 and Q

# %% [markdown]
# ### Select central region in R

# %% [markdown]
# #### The effect is to reduce the dependence of geometrical corrections

# %%
dst_R     = dst[dst.R < 100]

# %%
plot_energy_distributions(dst_R, krBins.Z, krBins.S1e, krBins.S2e, krBins.S2q, figsize=(14,12))
plt.savefig(summary_outputs+'s1s2q.png')

# %% [markdown]
# ### Select central region in Z
#
# - The effect is to reduce the dependence of lifetime

# %%
dst_core     = dst_R[dst_R.Z < 200]

# %% [markdown]
# ### Energy in core

# %%
(_) = h1d(dst_core.S2e, bins = 50, range =(3000,14000), legendloc='upper left')

# %% [markdown]
# ### Apply bootstrap corrections.
#
# - One can correct S2e and S2q by geometrical corrections using an existing map (a bootstrap map). This has the effect to reduce the geometrical dependence on both distributions, permitting an additional filtering

# %%
kre = kr_event(dst)

# %%
bootstrap_correction_filename = os.path.expandvars(bootstrap_correction_filename)
calibrate = corrections.Calibration(bootstrap_correction_filename)
E, Q = calibrate(kre.X, kre.Y, None, kre.T, kre.S2e, kre.S2q)

# %%
kge = kr_event(dst, DT, E, Q)

# %%
(_) = h1d(kge.E, bins = 50, range =(3000,12000))

# %% [markdown]
# #### Plot of E and Q corrected vs Z shows much less spread (XY corrections applied only remaining LT corrections)

# %%
nevt = h2d(dst.Z, E, krNbins.Z, krNbins.S2e, krRanges.Z, krRanges.S2e, 
           pltLabels=PlotLabels(x='Z', y='E corrected', title='E corrected vs Z'),
           profile=True,
           figsize=(10,6))

# %%
nevt = h2d(dst.Z, Q, krNbins.Z, krNbins.S2q, krRanges.Z, krRanges.S2q, 
           pltLabels=PlotLabels(x='Z', y='Q corrected', title='Q corrected vs Z'),
           profile=True,
           figsize=(10,6))

# %% [markdown]
# ### Filter

# %%
range_krs2 = (7e+3,12e+3)

# %%
num_bins = 50
num_in_band = 0
while num_in_band == 0 and num_bins >= 5:
    sel_krband, fpl, fph, hp, pp = selection_in_band(kre.Z, E,
                                                     range_z = krRanges.Z,
                                                     range_e = range_krs2,
                                                     nbins_z = num_bins,
                                                     nbins_e = num_bins,
                                                     nsigma  = 3.5)
    readout = selection_info(sel_krband, 'Kr band')
    readout = readout[readout.find(': ')+2:]
    readout = readout[:readout.find(' ')]
    num_in_band = int(readout)
    num_bins -= 1
print('Final number of bins =', num_bins)

# %%
plot_selection_in_band(fpl, fph, hp, pp)

# %%
selection_info(sel_krband, 'Kr band')

# %%
kges = kr_event(dst, DT, E, Q, sel_mask=sel_krband)

# %% [markdown]
# ### Energy before and after filter

# %%
fig = plt.figure(figsize=(12,6))
ax      = fig.add_subplot(1, 2, 1)
(_)     = h1(kge.E,  bins = 50, range =(3000,12000))
plot_histo(PlotLabels('E (pes)','Entries','Pre-filter'), ax, legendloc='upper left')
ax      = fig.add_subplot(1, 2, 2)
(_)     = h1(kges.E,  bins = 50, range =(3000,12000))
plot_histo(PlotLabels('E (pes)','Entries','Post-filter'), ax, legendloc='upper left')
plt.tight_layout()

# %%
nevt = h2d(kges.Z, kges.E, krNbins.Z, krNbins.S2e, krRanges.Z, krRanges.S2e, 
           pltLabels=PlotLabels(x='Z', y='E corrected', title='E corrected vs Z post filter'),
           profile=True,
           figsize=(10,6))

# %%
nevt = h2d(kges.Z, kges.Q, krNbins.Z, krNbins.S2q, krRanges.Z, krRanges.S2q, 
           pltLabels=PlotLabels(x='Z', y='Q corrected', title='Q corrected vs Z post-filter'),
           profile=True,
           figsize=(10,6))

# %% [markdown]
# #### Notice how the filter cleans up the energy distributions.

# %% [markdown]
# ### Time evolution

# %%
fig = plt.figure(figsize=(10,6))
ax      = fig.add_subplot(1, 1, 1)
(_)    = h1(kge.T, bins=500, range = (kge.T.min(), kge.T.max()), color='red', stats=False, lbl='pre-sel')
plot_histo(PlotLabels('Time','Entries',''), ax)
(_)    = h1(kges.T, bins=500, range = (kges.T.min(), kges.T.max()), color='blue',stats=False, lbl='post-sel')
plot_histo(PlotLabels('Time','Entries',''), ax)

# %% [markdown]
# #### event density is constant, indicating a stable run

# %% [markdown]
# ### S1 and Corrected E and Q as a function of T

# %%
nevt = h2d(kges.T, kges.S1e, krNbins.T, krNbins.S1e, krRanges.T, krRanges.S1e, 
           pltLabels=PlotLabels(x='T', y='S1 corrected', title='S1 vs T post-filter'),
           profile=True,
           figsize=(10,6))

# %%
nevt = h2d(kges.T, kges.E, krNbins.T, krNbins.S2e, krRanges.T, krRanges.S2e, 
           pltLabels=PlotLabels(x='T', y='E corrected', title='E corrected vs T post-filter'),
           profile=True,
           figsize=(10,6))

# %%
nevt = h2d(kges.T, kges.Q, krNbins.T, krNbins.S2q, krRanges.T, krRanges.S2q, 
           pltLabels=PlotLabels(x='T', y='Q corrected', title='Q corrected vs T post-filter'),
           profile=True,
           figsize=(10,6))

# %% [markdown]
# ### All amplitudes are constant as a function of time in an stable run

# %% [markdown]
# ### Select dst

# %%
dsts = dst[sel_krband]

# %% [markdown]
# ### X vs Y again

# %%
nevt = h2d(dsts.X, dsts.Y, krNbins.X, krNbins.Y, krRanges.X, krRanges.Y, 
           pltLabels=PlotLabels(x='X (mm)', y='Y (mm)', title='X vs Y post-filter'),
           profile=False,
           figsize=(10,8))

# %% [markdown]
# ### Spatial distributions

# %% [markdown]
# #### In R and Z

# %%
fig = plt.figure(figsize=(14,6))
ax      = fig.add_subplot(1, 2, 1)
(_)    = h1(kge.R, bins=50, range = (0,200), color='red', stats=False, lbl='pre-sel')
plot_histo(PlotLabels('R','Entries',''), ax)
(_)   = h1(kges.R, bins=50, range = (0,200), color='blue',stats=False, lbl='post-sel')
plot_histo(PlotLabels('R','Entries',''), ax)
ax      = fig.add_subplot(1, 2, 2)
(_)    = h1(kge.Z, bins=50, range = (0,550), color='red', stats=False, lbl='pre-sel')
plot_histo(PlotLabels('Z','Entries',''), ax)
(_)    = h1(kges.Z, bins=50, range = (0,550), color='blue',stats=False, lbl='post-sel')
plot_histo(PlotLabels('Z','Entries',''), ax)
plt.tight_layout()

# %% [markdown]
# #### In X Y

# %%
fig = plt.figure(figsize=(14,6))
ax      = fig.add_subplot(1, 2, 1)
(_)    = h1(kge.X, bins=50, range = (-200,200), color='red', stats=False, lbl='pre-sel')
plot_histo(PlotLabels('X','Entries',''), ax)
(_)    = h1(kges.X, bins=50, range = (-200,200), color='blue',stats=False, lbl='post-sel')
plot_histo(PlotLabels('X','Entries',''), ax)
ax      = fig.add_subplot(1, 2, 2)
(_)    = h1(kge.Y, bins=50, range = (-200,200), color='red', stats=False, lbl='pre-sel')
plot_histo(PlotLabels('X','Entries',''), ax)
(_)    = h1(kges.Y, bins=50, range = (-200,200), color='blue',stats=False, lbl='post-sel')
plot_histo(PlotLabels('Y','Entries',''), ax)
plt.tight_layout()

# %% [markdown]
# ### Charge and SiPM distributions

# %%
fig = plt.figure(figsize=(14,6))
ax      = fig.add_subplot(1, 2, 1)
(_)    = h1(kge.Q, bins=50, range = (0,800), color='red', stats=False, lbl='pre-sel')
plot_histo(PlotLabels('Qg','Entries',''), ax)
(_)    = h1(kges.Q, bins=50, range = (0,800), color='blue',stats=False, lbl='post-sel')
plot_histo(PlotLabels('Qg','Entries',''), ax)
ax      = fig.add_subplot(1, 2, 2)
(_)    = h1(dst.Nsipm, bins=50, range = (0,50), color='red', stats=False, lbl='pre-sel')
plot_histo(PlotLabels('Nsipm','Entries',''), ax)
(_)    = h1(dsts.Nsipm, bins=50, range = (0,50), color='blue',stats=False, lbl='post-sel')
plot_histo(PlotLabels('Nsipm','Entries',''), ax)
plt.tight_layout()

# %% [markdown]
# ### Write DST (merged and fiducial)

# %%
dst.columns

# %%
#del dst['index']
print('Time after loading to before writing =', round(time.time() - last_time))
last_time = time.time()

# %%
bash_mkdir = "mkdir " + os.environ['IC_DATA']+analysis_tag
process = subprocess.Popen(bash_mkdir, stdout=subprocess.PIPE, shell=True).wait()
bash_mkdir = "mkdir " + output_dst_filename[:output_dst_filename.rfind('/')+1]
process = subprocess.Popen(bash_mkdir, stdout=subprocess.PIPE, shell=True).wait()

# %%
if (write_filtered_dst):
    print('writing filtered dst ', output_dst_filename)
    kdst_write(dsts, output_dst_filename);
print('Time to write =', round(time.time() - last_time))
print('Full notebook time =', round(time.time() - t0))

# %% [markdown]
# ## End of NB
