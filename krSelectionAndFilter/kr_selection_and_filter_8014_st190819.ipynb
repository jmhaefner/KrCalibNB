# %% [markdown]
# # Selection of krypton events in terms of S1 and S2

# %% [markdown]
# ## Authors: JMH, JAH, GML, JJGC

# %% [markdown]
# ### Software: KrCalib : https://github.com/nextic/KrCalib/

# %% [markdown]
# ### Description:
#
# - run = 8014

# %%
import time
print("Last updated on ", time.asctime())
# Out:
# Last updated on  Tue May 26 16:18:39 2020

# %%
run_number  = 8014
file_range  = 0, 3441 
num_files = 2441
tags        = 'v1.2.0_20191122_krbg'
analysis_tag = 'st190819'

# Just for testing
# run_number  = 7376
# file_range  = 0, 8798 
# num_files = 8798
# tags        = 'v0.9.9_20190111_krbg'
# analysis_tag = 'st190819'

if num_files > 7729:
    num_xy_bins = 100
else:
    num_xy_bins = 50

t0 = time.time()
last_time = t0

input_path  = f"$IC_DATA/kdst"
output_path = f"$IC_DATA/"+analysis_tag+"/dst"
log_path    = f"$IC_DATA/"+analysis_tag+"/log"
trigger     = 'trigger1'
summary_outputs = "/Users/jmhaefner/Development/KryptonCalibration/KrCalibNB_JMH/KrCalibNB/doc/img/r"+str(run_number)+analysis_tag+"/"

bootstrap_correction_filename   = f"$IC_DATA/maps/kr_corrections_run6165.h5"
write_filtered_dst = True

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = 10, 8
plt.rcParams["font.size"     ] = 14

# %%
import os
import time
import datetime 
import numpy as np
import pandas as pd
import tables            as tb
import random
import glob
import seaborn as sns
sns.set()

# %%
from  invisible_cities.io.dst_io              import load_dsts
from  invisible_cities.core .core_functions   import in_range
from  invisible_cities.core.system_of_units_c import units

# %%
from krcal.core.io_functions       import filenames_from_paths
from krcal.core.io_functions       import write_monitor_vars
from krcal.core.io_functions       import kdst_write
from krcal.core.histo_functions    import h1, h1d, h2d, plot_histo

# %%
from krcal.core.kr_types           import PlotLabels
from krcal.core.ranges_and_bins_functions      import kr_ranges_and_bins
from krcal.core.analysis_functions import kr_event
from krcal.core.analysis_functions import selection_info
from krcal.core.analysis_functions import selection_in_band
from krcal.core.analysis_functions import plot_selection_in_band
from krcal.core.s1s2_functions     import s1d_from_dst
from krcal.core.s1s2_functions     import s2d_from_dst
from krcal.core.s1s2_functions     import plot_s1histos
from krcal.core.s1s2_functions     import plot_s2histos

# %%
from krcal.core.plt_functions      import plot_xy_density
from krcal.core.plt_functions      import plot_s1_vs_z
from krcal.core.plt_functions      import plot_s2_vs_z
from krcal.core.plt_functions      import plot_s2_vs_s1
from krcal.core.plt_functions      import plot_q_vs_s2
from krcal.core.plt_functions      import plot_energy_distributions
from krcal.core.plt_functions      import plot_energy_vs_t

# %%
import krcal.dev.corrections       as corrections 
import krcal.utils.hst_extend_functions as hst

# %%
from krcal.core.core_functions          import time_delta_from_time

# %% [markdown]
# ### Create vals file

# %%
# vals
import subprocess

# %%
# vals
vals_dir_loc = '/Users/jmhaefner/Development/KryptonCalibration/KrCalibNB_JMH/KrCalibNB/doc/data_'+str(run_number)+analysis_tag+'/'
bash_mkdir = "mkdir " + vals_dir_loc
process = subprocess.Popen(bash_mkdir, stdout=subprocess.PIPE, shell=True).wait()

# %%
# vals
vals_loc = vals_dir_loc + 'vals_'+str(run_number)+'.txt'
bash_touch = "touch " + vals_loc
process = subprocess.Popen(bash_touch, stdout=subprocess.PIPE, shell=True).wait()

# %%
# vals
summary_vals = open(vals_loc, 'w') # start by erasing the old file, then just append in later use.
summary_vals.write('runNumber='+str(run_number)+'\n')
summary_vals.write('lastFile='+str(file_range[1])+'\n')
summary_vals.close()

# %% [markdown]
# ### Input/output

# %%
input_dst_filenames, output_dst_filename, log_filename = filenames_from_paths(run_number,
                                                                              input_path,
                                                                              output_path,
                                                                              log_path,
                                                                              trigger,
                                                                              tags,
                                                                              file_range)
                                                                              
print(f'input dsts:\n first = {input_dst_filenames[0]}\n last = {input_dst_filenames[-1]}')
print(f"output dst = {output_dst_filename}")
print(f"log file   = {log_filename}")           

print('time before dst load =', round(time.time() - last_time))
last_time = time.time()
# Out:
# input dsts:
#  first = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0000_8014_trigger1_v1.2.0_20191122_krbg.h5
#  last = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_3440_8014_trigger1_v1.2.0_20191122_krbg.h5
# output dst = /Volumes/NEXT_data/IC_Data//st190819/dst/dst_8014_trigger1_0000_3440.h5
# log file   = /Volumes/NEXT_data/IC_Data//st190819/log/log_8014_trigger1_0000_3440.h5
# time before dst load = 6

# %%
dst_full           = load_dsts(input_dst_filenames, "DST", "Events")
print('time to load dst =', round(time.time() - last_time))
last_time = time.time()
# Out:
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0000_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0001_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0002_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0003_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0004_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0005_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0006_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0007_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0008_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0009_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0010_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0011_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0012_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0013_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0014_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0015_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0016_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0017_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0018_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0019_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0020_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0021_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0022_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0023_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0024_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0025_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0026_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0027_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0028_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0029_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0030_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0031_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0032_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0033_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0034_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0035_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0036_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0037_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0038_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0039_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0040_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0041_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0042_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0043_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0044_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0045_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0046_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0047_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0048_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0049_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0050_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0051_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0052_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0053_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0054_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0055_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0056_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0057_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0058_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0059_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0060_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0061_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0062_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0063_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0064_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0065_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0066_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0067_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0068_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0069_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0070_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0071_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0072_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0073_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0074_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0075_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0076_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0077_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0078_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0079_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0080_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0081_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0082_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0083_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0084_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0085_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0086_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0087_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0088_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0089_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0090_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0091_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0092_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0093_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0094_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0095_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0096_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0097_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0098_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0099_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0100_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0101_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0102_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0103_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0104_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0105_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0106_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0107_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0108_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0109_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0110_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0111_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0112_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0113_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0114_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0115_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0116_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0117_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0118_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0119_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0120_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0121_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0122_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0123_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0124_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0125_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0126_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0127_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0128_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0129_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0130_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0131_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0132_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0133_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0134_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0135_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0136_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0137_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0138_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0139_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0140_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0141_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0142_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0143_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0144_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0145_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0146_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0147_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0148_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0149_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0150_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0151_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0152_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0153_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0154_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0155_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0156_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0157_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0158_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0159_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0160_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0161_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0162_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0163_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0164_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0165_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0166_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0167_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0168_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0169_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0170_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0171_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# ...
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0943_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0944_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0945_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0946_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0947_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0948_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0949_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0950_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0951_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0952_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0953_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0954_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0955_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0956_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0957_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0958_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0959_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0960_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0961_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0962_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0963_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0964_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0965_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0966_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0967_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0968_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0969_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0970_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0971_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0972_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0973_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0974_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0975_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0976_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0977_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0978_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0979_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0980_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0981_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0982_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0983_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0984_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0985_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0986_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0987_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0988_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0989_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0990_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0991_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0992_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0993_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0994_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0995_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0996_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0997_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0998_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_current/IC/invisible_cities/io/dst_io.py:25: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/8014/kdst_0999_8014_trigger1_v1.2.0_20191122_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# time to load dst = 69

# %%
unique_events = ~dst_full.event.duplicated()

number_of_S2s_full  = np.size         (unique_events)
number_of_evts_full = np.count_nonzero(unique_events)

print(f"Total number of S2s   : {number_of_S2s_full} ")
print(f"Total number of events: {number_of_evts_full}")

# vals
summary_vals = open(vals_loc, 'a')
summary_vals.write(f'totalNumS2={number_of_S2s_full}\n')
summary_vals.write(f'totalNumEvt={number_of_evts_full}\n')
summary_vals.close()
# Out:
# Total number of S2s   : 761428
# Total number of events: 654198

# %%
dst_full.columns
# Out:
# Index(['event', 'time', 's1_peak', 's2_peak', 'nS1', 'nS2', 'S1w', 'S1h',
#        'S1e', 'S1t', 'S2w', 'S2h', 'S2e', 'S2q', 'S2t', 'Nsipm', 'DT', 'Z',
#        'Zrms', 'X', 'Y', 'R', 'Phi', 'Xrms', 'Yrms'],
#       dtype='object')

# %%
ntot = len(dst_full)
print(f"length of dst = {ntot}")
# Out:
# length of dst = 761428

# %% [markdown]
# ### S1/S2

# %%
n, b, _, _ = h1d(dst_full.nS1.values, bins = 10, range = (0,10),
           pltLabels=PlotLabels(x='nS1', y='Entries', title='nS1'))

# %%
fnS1 = n[n.argmax()]/np.sum(n)
print(f'fraction of S1s = {fnS1}')
# Out:
# fraction of S1s = 0.7717223427559795

# %% [markdown]
# #### Fraction of events with 1 S1 is 0.5, due to grass and high energy events. For Krypton select events with 1 S1

# %% [markdown]
# ### Select events with 1 S1

# %%
dst1s1 = dst_full[dst_full.nS1==1]

# %%
n, b, _, _ = h1d(dst1s1.nS2.values, bins = 10, range = (0,10),
           pltLabels=PlotLabels(x='nS2', y='Entries', title='nS2'))

# %% [markdown]
# #### For Krypton select events with only 1 S2

# %%
fnS2 = n[n.argmax()]/np.sum(n)
print(f'fraction of S2s = {fnS2}')
# Out:
# fraction of S2s = 0.9773591712884885

# %% [markdown]
# ### Select events with 1 S2

# %%
dst    = dst1s1[dst1s1.nS2==1]

# %%
n_full   = len(dst)
eff = n_full   / ntot 
print(f"Total number of events with 1 s1 and 1 s2 : {n_full}: selection eff = {eff} ")

# vals
summary_vals = open(vals_loc, 'a')
summary_vals.write(f'fracS1={round(fnS1,2)}\n')
summary_vals.write(f'fracS2={round(fnS2,2)}\n')
summary_vals.write(f'fracS1S2={round(eff,2)}\n')
summary_vals.close()
# Out:
# Total number of events with 1 s1 and 1 s2 : 574307: selection eff = 0.7542499093807951

# %% [markdown]
# ### S1 and S2 distributions

# %%
s1d = s1d_from_dst(dst)

# %%
bash_mkdir = "mkdir " + summary_outputs
process = subprocess.Popen(bash_mkdir, stdout=subprocess.PIPE, shell=True).wait()

# %%
plot_s1histos(dst,  s1d, bins=20, figsize=(10,10))
plt.savefig(summary_outputs+'s1.png')

# %% [markdown]
# ### Fiducial selection in S1

# %% [markdown]
# #### 2 < S1e < 25 pes, which cuts off very low and high energy events

# %%
s1e_range =(3, 25)

# vals
summary_vals = open(vals_loc, 'a')
summary_vals.write(f's1Min={s1e_range[0]}\n')
summary_vals.write(f's1Max={s1e_range[1]}\n')
summary_vals.close()

# %%
dst_s1e    = dst[in_range(dst.S1e, *s1e_range)]

# %%
s1d = s1d_from_dst(dst_s1e, range_s1e = s1e_range)
plot_s1histos(dst_s1e,  s1d, bins=20, figsize=(10,10))

# %%
dst = dst_s1e
s2d = s2d_from_dst(dst)
plot_s2histos(dst, s2d, bins=20, emin=1000, emax=15000, figsize=(10,10))
plt.savefig(summary_outputs+'s2.png')

# %% [markdown]
# ### Fiducial selection in S2

# %%
Nsipm_min = 15 
s2e_range =(3000, 13000)
s2w_range =(5, 15)
s2q_range =(200, 800)

# vals
summary_vals = open(vals_loc, 'a')
summary_vals.write(f's2MinPMT={s2e_range[0]}\n')
summary_vals.write(f's2MaxPMT={s2e_range[1]}\n')
summary_vals.write(f's2MinQ={s2q_range[0]}\n')
summary_vals.write(f's2MaxQ={s2q_range[1]}\n')
summary_vals.write(f'widthMin={s2w_range[0]}\n')
summary_vals.write(f'widthMax={s2w_range[1]}\n')
summary_vals.write(f'numSipmMin={Nsipm_min}\n')
summary_vals.close()

# %%
dst_sipm    = dst[dst.Nsipm >Nsipm_min] 
dst_s2e    = dst_sipm[in_range(dst_sipm.S2e, *s2e_range)] 
dst_s2w    = dst_s2e[in_range(dst_s2e.S2w, *s2w_range)]
dst_s2q    = dst_s2w[in_range(dst_s2w.S2q, *s2q_range)]
dst = dst_s2q

# %%
s2d = s2d_from_dst(dst_s2e)
plot_s2histos(dst, s2d, bins=20, emin=1000, emax=15000, figsize=(10,10))

# %% [markdown]
# ### Time differences in seconds

# %%
dst_time = dst.sort_values('event')
T       = dst_time.time.values
DT      = time_delta_from_time(T)

# %% [markdown]
# ### Define ranges and bins

# %%
krTimes, krRanges, krNbins, krBins = kr_ranges_and_bins(dst,
                                                        xxrange   = (-220,  220),
                                                        yrange    = (-220,  220),
                                                        zrange    = (10,  550),
                                                        s2erange  = s2e_range,
                                                        s1erange  = s1e_range,
                                                        s2qrange  = s2q_range,
                                                        xnbins    = num_xy_bins,
                                                        ynbins    = num_xy_bins,
                                                        znbins    = 50,
                                                        s2enbins  = 50,
                                                        s1enbins  = 50,
                                                        s2qnbins  = 50,
                                                        tpsamples = 3600) # tsamples in seconds

# %% [markdown]
# ### Time
# - Extension in hours of data sample considered

# %%
plt.plot(krTimes.timeStamps)
plt.savefig(summary_outputs+'runTime.png')

# %%
# vals
full_final_datetime = str(krTimes.timeStamps[-1])
final_date = full_final_datetime[:full_final_datetime.find(' ')]

# Once you have the date, find the temperature on that date.
import codecs

ctrl = 'SNS'

def itemize(line):
    items = []
    while len(line) > 0:
        if not line.find('\t') == -1:
            potential_item = line[:line.find('\t')]
            potential_item = potential_item.strip()
            if not potential_item == "":
                items.append(potential_item)
            line = line[line.find('\t')+1:]
        elif line.find('\n') == -1:
            items.append(line)
            line = ""
        else:
            line = ""
    return items

vessel_temps = []
param_of_interest = "NEW"

text_path = "/Users/jmhaefner/Dropbox/Data/" + ctrl + "_Data_Report_" + final_date + ".txt"

if os.path.isfile(text_path):
    data_file = codecs.open(text_path, 'r', encoding='ISO-8859-1')
    data_lines = data_file.readlines()

    parameters = itemize(data_lines[2])
    first_data = itemize(data_lines[3])

    for i in range(len(parameters)):
        try:
            print_params = parameters[i]+'='+first_data[i]
            #print(print_params)
        except:
            # print('Failed to find a value for param', [parameters[i]])
            parameters.pop(i)
            i -= 1

    for i in range(len(parameters)):
        for j in range(3,len(data_lines)):
            if parameters[i] == param_of_interest:
                itemized = itemize(data_lines[j])
                value = float(itemized[i].replace(',', '.'))
                vessel_temps.append(value)

    day_temp = sum(vessel_temps)/(1.0 * len(vessel_temps))
    print('The day temp on '+final_date+' was '+str(round(day_temp,1)))
else:
    day_temp = 'nan'
    print('UNABLE TO FIND TEMPERATURE FILE '+text_path)

summary_vals = open(vals_loc, 'a')
summary_vals.write('date='+final_date+'\n')
if day_temp != 'nan':
    summary_vals.write('labTempC='+str(round(day_temp,1))+'\n')
else:
    summary_vals.write('labTempC='+day_temp)
summary_vals.close()
# Out:
# The day temp on 2020-05-21 was 20.1

# %%
kge = kr_event(dst, DT, dst.S2e, dst.S2q)

# %%
fig = plt.figure(figsize=(10,6))
ax      = fig.add_subplot(1, 1, 1)
(_)    = h1(kge.DT, bins=500, range = (kge.DT[0], kge.DT[-1]), color='red', stats=False, lbl='pre-sel')
plt.savefig(summary_outputs+'runEvt.png')

# %% [markdown]
# ### Control distributions

# %%
nevt = h2d(dst.X, dst.Y, krNbins.X, krNbins.Y, krRanges.X, krRanges.Y, 
           pltLabels=PlotLabels(x='X (mm)', y='Y (mm)', title='X vs Y'),
           profile=False,
           figsize=(10,8))
plt.savefig(summary_outputs+'xy.png')

# %%
nevt = h2d(dst.Z, dst.S1e, krNbins.Z, krNbins.S1e, krRanges.Z, (0,20), 
           pltLabels=PlotLabels(x='Z (mm)', y='S1e (pes)', title='S1 vs Z'),
           profile=False,
           figsize=(10,8))

# %% [markdown]
# #### S1 vs Z distribution:
#
# - Concentrated at low Z: This is due to the fact that gas flow is higher near the anode, and thus there is more krypton near the anode than near the cathode.
# - Increases as a function of Z. The closer to the cathode the larger S1
# - Spread is large: This is due to large variation of solid angle, depending on (X,Y)

# %%
nevt = h2d(dst.Z, dst.S2e, krNbins.Z, krNbins.S1e, krRanges.Z, krRanges.S2e, 
           pltLabels=PlotLabels(x='Z (mm)', y='S2e (pes)', title='S2 vs Z'),
           profile=True,
           figsize=(10,8))

# %% [markdown]
# #### S2 vs Z distribution:
#
# - Concentrated at low Z: This is due to the fact that gas flow is higher near the anode, and thus there is more krypton near the anode than near the cathode.
# - Decreases as a function of Z, due to lifetime
# - Spread is large: This is due to large variation of solid angle, depending on (X,Y)

# %%
nevt = h2d(dst.S1e, dst.S2e, krNbins.S1e, krNbins.S2e, krRanges.S1e, krRanges.S2e, 
           pltLabels=PlotLabels(x='S1e (pes)', y='S2e (pes)', title='S2 vs S1'),
           profile=False,
           figsize=(10,8))

# %% [markdown]
# #### S2 vs S1 distribution:
#
# - Small anti-correlation (more S2 less S1).

# %%
nevt = h2d(dst.S2e, dst.S2q, krNbins.S2e, krNbins.S2q, krRanges.S2e, krRanges.S2q, 
           pltLabels=PlotLabels(x='S2e (pes)', y='S2q (pes)', title='S2e vs S2q'),
           profile=False,
           figsize=(10,8))

# %% [markdown]
# #### S2 vs Q distribution:
#
# - Clear correlation between S2 and Q

# %% [markdown]
# ### Select central region in R

# %% [markdown]
# #### The effect is to reduce the dependence of geometrical corrections

# %%
dst_R     = dst[dst.R < 100]

# %%
plot_energy_distributions(dst_R, krBins.Z, krBins.S1e, krBins.S2e, krBins.S2q, figsize=(14,12))
plt.savefig(summary_outputs+'s1s2q.png')

# %% [markdown]
# ### Select central region in Z
#
# - The effect is to reduce the dependence of lifetime

# %%
dst_core     = dst_R[dst_R.Z < 200]

# %% [markdown]
# ### Energy in core

# %%
(_) = h1d(dst_core.S2e, bins = 50, range =(3000,14000), legendloc='upper left')

# %% [markdown]
# ### Apply bootstrap corrections.
#
# - One can correct S2e and S2q by geometrical corrections using an existing map (a bootstrap map). This has the effect to reduce the geometrical dependence on both distributions, permitting an additional filtering

# %%
kre = kr_event(dst)

# %%
bootstrap_correction_filename = os.path.expandvars(bootstrap_correction_filename)
calibrate = corrections.Calibration(bootstrap_correction_filename)
E, Q = calibrate(kre.X, kre.Y, None, kre.T, kre.S2e, kre.S2q)

# %%
kge = kr_event(dst, DT, E, Q)

# %%
(_) = h1d(kge.E, bins = 50, range =(3000,12000))

# %% [markdown]
# #### Plot of E and Q corrected vs Z shows much less spread (XY corrections applied only remaining LT corrections)

# %%
nevt = h2d(dst.Z, E, krNbins.Z, krNbins.S2e, krRanges.Z, krRanges.S2e, 
           pltLabels=PlotLabels(x='Z', y='E corrected', title='E corrected vs Z'),
           profile=True,
           figsize=(10,6))

# %%
nevt = h2d(dst.Z, Q, krNbins.Z, krNbins.S2q, krRanges.Z, krRanges.S2q, 
           pltLabels=PlotLabels(x='Z', y='Q corrected', title='Q corrected vs Z'),
           profile=True,
           figsize=(10,6))

# %% [markdown]
# ### Filter

# %%
range_krs2 = (7e+3,12e+3)

# %%
num_bins = 50
num_in_band = 0
while num_in_band == 0 and num_bins >= 5:
    sel_krband, fpl, fph, hp, pp = selection_in_band(kre.Z, E,
                                                     range_z = krRanges.Z,
                                                     range_e = range_krs2,
                                                     nbins_z = num_bins,
                                                     nbins_e = num_bins,
                                                     nsigma  = 3.5)
    readout = selection_info(sel_krband, 'Kr band')
    readout = readout[readout.find(': ')+2:]
    readout = readout[:readout.find(' ')]
    num_in_band = int(readout)
    num_bins -= 1
print('Final number of bins =', num_bins)
# Out:
# Total number of selected candidates Kr band: 500178 (92.8 %)
# Final number of bins = 49
# /Users/jmhaefner/Development/KryptonCalibration/KrCalibTEMP/ICAROS/krcal/core/fit_functions.py:47: UserWarning: nof = 0 in chi2 calculation, return chi2 = {chi2_}
#   warnings.warn('nof = 0 in chi2 calculation, return chi2 = {chi2_}', UserWarning)
# /Users/jmhaefner/Development/KryptonCalibration/KrCalibTEMP/ICAROS/krcal/core/fit_functions.py:47: UserWarning: nof = 0 in chi2 calculation, return chi2 = {chi2_}
#   warnings.warn('nof = 0 in chi2 calculation, return chi2 = {chi2_}', UserWarning)

# %%
plot_selection_in_band(fpl, fph, hp, pp)

# %%
selection_info(sel_krband, 'Kr band')
# Out:
# Total number of selected candidates Kr band: 500178 (92.8 %)
# 'Total number of selected candidates Kr band: 500178 (92.8 %)'

# %%
kges = kr_event(dst, DT, E, Q, sel_mask=sel_krband)

# %% [markdown]
# ### Energy before and after filter

# %%
fig = plt.figure(figsize=(12,6))
ax      = fig.add_subplot(1, 2, 1)
(_)     = h1(kge.E,  bins = 50, range =(3000,12000))
plot_histo(PlotLabels('E (pes)','Entries','Pre-filter'), ax, legendloc='upper left')
ax      = fig.add_subplot(1, 2, 2)
(_)     = h1(kges.E,  bins = 50, range =(3000,12000))
plot_histo(PlotLabels('E (pes)','Entries','Post-filter'), ax, legendloc='upper left')
plt.tight_layout()

# %%
nevt = h2d(kges.Z, kges.E, krNbins.Z, krNbins.S2e, krRanges.Z, krRanges.S2e, 
           pltLabels=PlotLabels(x='Z', y='E corrected', title='E corrected vs Z post filter'),
           profile=True,
           figsize=(10,6))

# %%
nevt = h2d(kges.Z, kges.Q, krNbins.Z, krNbins.S2q, krRanges.Z, krRanges.S2q, 
           pltLabels=PlotLabels(x='Z', y='Q corrected', title='Q corrected vs Z post-filter'),
           profile=True,
           figsize=(10,6))

# %% [markdown]
# #### Notice how the filter cleans up the energy distributions.

# %% [markdown]
# ### Time evolution

# %%
fig = plt.figure(figsize=(10,6))
ax      = fig.add_subplot(1, 1, 1)
(_)    = h1(kge.T, bins=500, range = (kge.T.min(), kge.T.max()), color='red', stats=False, lbl='pre-sel')
plot_histo(PlotLabels('Time','Entries',''), ax)
(_)    = h1(kges.T, bins=500, range = (kges.T.min(), kges.T.max()), color='blue',stats=False, lbl='post-sel')
plot_histo(PlotLabels('Time','Entries',''), ax)

# %% [markdown]
# #### event density is constant, indicating a stable run

# %% [markdown]
# ### S1 and Corrected E and Q as a function of T

# %%
nevt = h2d(kges.T, kges.S1e, krNbins.T, krNbins.S1e, krRanges.T, krRanges.S1e, 
           pltLabels=PlotLabels(x='T', y='S1 corrected', title='S1 vs T post-filter'),
           profile=True,
           figsize=(10,6))

# %%
nevt = h2d(kges.T, kges.E, krNbins.T, krNbins.S2e, krRanges.T, krRanges.S2e, 
           pltLabels=PlotLabels(x='T', y='E corrected', title='E corrected vs T post-filter'),
           profile=True,
           figsize=(10,6))

# %%
nevt = h2d(kges.T, kges.Q, krNbins.T, krNbins.S2q, krRanges.T, krRanges.S2q, 
           pltLabels=PlotLabels(x='T', y='Q corrected', title='Q corrected vs T post-filter'),
           profile=True,
           figsize=(10,6))

# %% [markdown]
# ### All amplitudes are constant as a function of time in an stable run

# %% [markdown]
# ### Select dst

# %%
dsts = dst[sel_krband]

# %% [markdown]
# ### X vs Y again

# %%
nevt = h2d(dsts.X, dsts.Y, krNbins.X, krNbins.Y, krRanges.X, krRanges.Y, 
           pltLabels=PlotLabels(x='X (mm)', y='Y (mm)', title='X vs Y post-filter'),
           profile=False,
           figsize=(10,8))

# %% [markdown]
# ### Spatial distributions

# %% [markdown]
# #### In R and Z

# %%
fig = plt.figure(figsize=(14,6))
ax      = fig.add_subplot(1, 2, 1)
(_)    = h1(kge.R, bins=50, range = (0,200), color='red', stats=False, lbl='pre-sel')
plot_histo(PlotLabels('R','Entries',''), ax)
(_)   = h1(kges.R, bins=50, range = (0,200), color='blue',stats=False, lbl='post-sel')
plot_histo(PlotLabels('R','Entries',''), ax)
ax      = fig.add_subplot(1, 2, 2)
(_)    = h1(kge.Z, bins=50, range = (0,550), color='red', stats=False, lbl='pre-sel')
plot_histo(PlotLabels('Z','Entries',''), ax)
(_)    = h1(kges.Z, bins=50, range = (0,550), color='blue',stats=False, lbl='post-sel')
plot_histo(PlotLabels('Z','Entries',''), ax)
plt.tight_layout()

# %% [markdown]
# #### In X Y

# %%
fig = plt.figure(figsize=(14,6))
ax      = fig.add_subplot(1, 2, 1)
(_)    = h1(kge.X, bins=50, range = (-200,200), color='red', stats=False, lbl='pre-sel')
plot_histo(PlotLabels('X','Entries',''), ax)
(_)    = h1(kges.X, bins=50, range = (-200,200), color='blue',stats=False, lbl='post-sel')
plot_histo(PlotLabels('X','Entries',''), ax)
ax      = fig.add_subplot(1, 2, 2)
(_)    = h1(kge.Y, bins=50, range = (-200,200), color='red', stats=False, lbl='pre-sel')
plot_histo(PlotLabels('X','Entries',''), ax)
(_)    = h1(kges.Y, bins=50, range = (-200,200), color='blue',stats=False, lbl='post-sel')
plot_histo(PlotLabels('Y','Entries',''), ax)
plt.tight_layout()

# %% [markdown]
# ### Charge and SiPM distributions

# %%
fig = plt.figure(figsize=(14,6))
ax      = fig.add_subplot(1, 2, 1)
(_)    = h1(kge.Q, bins=50, range = (0,800), color='red', stats=False, lbl='pre-sel')
plot_histo(PlotLabels('Qg','Entries',''), ax)
(_)    = h1(kges.Q, bins=50, range = (0,800), color='blue',stats=False, lbl='post-sel')
plot_histo(PlotLabels('Qg','Entries',''), ax)
ax      = fig.add_subplot(1, 2, 2)
(_)    = h1(dst.Nsipm, bins=50, range = (0,50), color='red', stats=False, lbl='pre-sel')
plot_histo(PlotLabels('Nsipm','Entries',''), ax)
(_)    = h1(dsts.Nsipm, bins=50, range = (0,50), color='blue',stats=False, lbl='post-sel')
plot_histo(PlotLabels('Nsipm','Entries',''), ax)
plt.tight_layout()

# %% [markdown]
# ### Write DST (merged and fiducial)

# %%
dst.columns
# Out:
# Index(['event', 'time', 's1_peak', 's2_peak', 'nS1', 'nS2', 'S1w', 'S1h',
#        'S1e', 'S1t', 'S2w', 'S2h', 'S2e', 'S2q', 'S2t', 'Nsipm', 'DT', 'Z',
#        'Zrms', 'X', 'Y', 'R', 'Phi', 'Xrms', 'Yrms'],
#       dtype='object')

# %%
#del dst['index']
print('Time after loading to before writing =', round(time.time() - last_time))
last_time = time.time()
# Out:
# Time after loading to before writing = 32

# %%
bash_mkdir = "mkdir " + os.environ['IC_DATA']+analysis_tag
process = subprocess.Popen(bash_mkdir, stdout=subprocess.PIPE, shell=True).wait()
bash_mkdir = "mkdir " + output_dst_filename[:output_dst_filename.rfind('/')+1]
process = subprocess.Popen(bash_mkdir, stdout=subprocess.PIPE, shell=True).wait()

# %%
if (write_filtered_dst):
    print('writing filtered dst ', output_dst_filename)
    kdst_write(dsts, output_dst_filename);
print('Time to write =', round(time.time() - last_time))
print('Full notebook time =', round(time.time() - t0))
# Out:
# writing filtered dst  /Volumes/NEXT_data/IC_Data//st190819/dst/dst_8014_trigger1_0000_3440.h5
# Time to write = 44
# Full notebook time = 151

# %% [markdown]
# ## End of NB
