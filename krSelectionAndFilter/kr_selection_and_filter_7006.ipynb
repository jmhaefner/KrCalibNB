# %% [markdown]
# # Selection of krypton events in terms of S1 and S2

# %% [markdown]
# ## Authors: JAH, GML, JJGC

# %% [markdown]
# ### Software: KrCalib : https://github.com/nextic/KrCalib/

# %% [markdown]
# ### Description:
#
# - run = 7006

# %%
import time
print("Last updated on ", time.asctime())
# Out:
# Last updated on  Mon Mar 18 17:20:56 2019

# %%
run_number  = 7006
file_range  = 0, 2837 
num_files = 2291
tags        = 'v0.9.9_20190111_krbg'

if num_files > 7729:
    num_xy_bins = 100
else:
    num_xy_bins = 50

t0 = time.time()
last_time = t0

input_path  = f"$IC_DATA/kdst"
output_path = f"$IC_DATA/dst"
log_path    = f"$IC_DATA/log"
trigger     = 'trigger1'
summary_outputs = "/Users/jmhaefner/Development/KryptonCalibration/KrCalibNB_JMH/KrCalibNB/doc/img/r"+str(run_number)+"/"

bootstrap_correction_filename   = f"$IC_DATA/maps/kr_corrections_run6165.h5"
write_filtered_dst = True

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = 10, 8
plt.rcParams["font.size"     ] = 14

# %%
import os
import time
import datetime 
import numpy as np
import pandas as pd
import tables            as tb
import random
import glob
import seaborn as sns
sns.set()

# %%
from  invisible_cities.io.dst_io              import load_dsts
from  invisible_cities.core .core_functions   import in_range
from  invisible_cities.core.system_of_units_c import units

# %%
from krcal.core.io_functions       import filenames_from_paths
from krcal.core.io_functions       import write_monitor_vars
from krcal.core.io_functions       import kdst_write
from krcal.core.histo_functions    import h1, h1d, h2d, plot_histo

# %%
from krcal.core.kr_types           import PlotLabels
from krcal.core.ranges_and_bins_functions      import kr_ranges_and_bins
from krcal.core.analysis_functions import kr_event
from krcal.core.analysis_functions import selection_info
from krcal.core.analysis_functions import selection_in_band
from krcal.core.analysis_functions import plot_selection_in_band
from krcal.core.s1s2_functions     import s1d_from_dst
from krcal.core.s1s2_functions     import s2d_from_dst
from krcal.core.s1s2_functions     import plot_s1histos
from krcal.core.s1s2_functions     import plot_s2histos

# %%
from krcal.core.plt_functions      import plot_xy_density
from krcal.core.plt_functions      import plot_s1_vs_z
from krcal.core.plt_functions      import plot_s2_vs_z
from krcal.core.plt_functions      import plot_s2_vs_s1
from krcal.core.plt_functions      import plot_q_vs_s2
from krcal.core.plt_functions      import plot_energy_distributions
from krcal.core.plt_functions      import plot_energy_vs_t

# %%
import krcal.dev.corrections       as corrections 
import krcal.utils.hst_extend_functions as hst

# %%
from krcal.core.core_functions          import time_delta_from_time

# %% [markdown]
# ### Create vals file

# %%
# vals
import subprocess

# %%
# vals
vals_dir_loc = '/Users/jmhaefner/Development/KryptonCalibration/KrCalibNB_JMH/KrCalibNB/doc/data_'+str(run_number)+'/'
bash_mkdir = "mkdir " + vals_dir_loc
process = subprocess.Popen(bash_mkdir, stdout=subprocess.PIPE, shell=True).wait()

# %%
# vals
vals_loc = vals_dir_loc + 'vals_'+str(run_number)+'.txt'
bash_touch = "touch " + vals_loc
process = subprocess.Popen(bash_touch, stdout=subprocess.PIPE, shell=True).wait()

# %%
# vals
summary_vals = open(vals_loc, 'w') # start by erasing the old file, then just append in later use.
summary_vals.write('runNumber='+str(run_number)+'\n')
summary_vals.write('lastFile='+str(file_range[1])+'\n')
summary_vals.close()

# %% [markdown]
# ### Input/output

# %%
input_dst_filenames, output_dst_filename, log_filename = filenames_from_paths(run_number,
                                                                              input_path,
                                                                              output_path,
                                                                              log_path,
                                                                              trigger,
                                                                              tags,
                                                                              file_range)
                                                                              
print(f'input dsts:\n first = {input_dst_filenames[0]}\n last = {input_dst_filenames[-1]}')
print(f"output dst = {output_dst_filename}")
print(f"log file   = {log_filename}")           

print('time before dst load =', round(time.time() - last_time))
last_time = time.time()
# Out:
# input dsts:
#  first = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0000_7006_trigger1_v0.9.9_20190111_krbg.h5
#  last = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_2836_7006_trigger1_v0.9.9_20190111_krbg.h5
# output dst = /Volumes/NEXT_data/IC_Data//dst/dst_7006_trigger1_0000_2836.h5
# log file   = /Volumes/NEXT_data/IC_Data//log/log_7006_trigger1_0000_2836.h5
# time before dst load = 6

# %%
dst_full           = load_dsts(input_dst_filenames, "DST", "Events")
print('time to load dst =', round(time.time() - last_time))
last_time = time.time()
# Out:
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0456_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0460_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0461_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0462_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0465_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0466_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0467_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0468_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0469_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0471_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0472_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0473_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0474_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0475_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0476_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0477_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0478_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0479_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0480_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0481_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0482_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0483_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0484_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0485_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0486_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0487_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0488_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0489_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0490_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0491_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0492_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0493_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0494_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0495_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0496_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0497_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0498_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0499_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0500_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0501_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0502_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0503_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0504_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0505_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0506_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0507_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0508_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0509_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0510_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0511_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0512_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0513_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0514_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0515_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0516_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0517_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0518_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0519_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0520_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0521_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0522_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0523_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0524_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0525_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0526_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0527_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0528_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0529_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0530_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0531_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0532_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0533_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0534_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0535_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0536_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0537_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0538_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0539_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0540_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0541_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0542_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0543_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0544_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0545_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0546_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0547_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0548_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0549_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0550_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0551_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0552_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0553_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0554_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0555_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0556_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0557_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0558_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0559_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0560_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0561_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0562_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0563_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0564_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0565_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0566_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0567_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0568_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0569_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0570_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0571_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0572_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0573_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0574_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0575_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0576_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0577_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0578_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0579_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0580_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0581_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0582_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0583_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0584_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0585_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0586_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0587_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0588_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0589_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0590_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0591_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0592_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0593_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0594_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0595_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0596_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0597_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0598_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0599_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0600_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0601_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0602_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0603_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0604_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0605_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0606_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0607_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0608_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0609_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0610_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0611_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0612_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0613_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0614_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0615_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0616_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0617_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0618_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0619_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0620_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0621_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0622_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0623_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0624_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0625_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0626_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0627_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0628_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0629_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0630_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0631_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0632_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0633_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# ...
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0951_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0952_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0953_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0954_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0955_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0956_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0957_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0958_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0959_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0960_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0961_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0962_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0963_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0964_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0965_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0966_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0967_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0968_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0969_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0970_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0971_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0972_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0973_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0974_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0975_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0976_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0977_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0978_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0979_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0980_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0981_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0982_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0983_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0984_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0985_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0986_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0987_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0988_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0989_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0990_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0991_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0992_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0993_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0994_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0995_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0996_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0997_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0998_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_0999_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_2811_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_2822_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_2828_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_2831_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_2833_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_2834_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_2835_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# /Users/jmhaefner/Documents/NEXT_code/IC_workshop/IC/invisible_cities/io/dst_io.py:21: UserWarning:  does not exist: file = /Volumes/NEXT_data/IC_Data//kdst/7006/kdst_2836_7006_trigger1_v0.9.9_20190111_krbg.h5
#   warnings.warn(f' does not exist: file = {filename} ', UserWarning)
# time to load dst = 70

# %%
unique_events = ~dst_full.event.duplicated()

number_of_S2s_full  = np.size         (unique_events)
number_of_evts_full = np.count_nonzero(unique_events)

print(f"Total number of S2s   : {number_of_S2s_full} ")
print(f"Total number of events: {number_of_evts_full}")

# vals
summary_vals = open(vals_loc, 'a')
summary_vals.write(f'totalNumS2={number_of_S2s_full}\n')
summary_vals.write(f'totalNumEvt={number_of_evts_full}\n')
summary_vals.close()
# Out:
# Total number of S2s   : 713822
# Total number of events: 627203

# %%
dst_full.columns
# Out:
# Index(['event', 'time', 's1_peak', 's2_peak', 'nS1', 'nS2', 'S1w', 'S1h',
#        'S1e', 'S1t', 'S2w', 'S2h', 'S2e', 'S2q', 'S2t', 'Nsipm', 'DT', 'Z',
#        'Zrms', 'X', 'Y', 'R', 'Phi', 'Xrms', 'Yrms'],
#       dtype='object')

# %%
ntot = len(dst_full)
print(f"length of dst = {ntot}")
# Out:
# length of dst = 713822

# %% [markdown]
# ### S1/S2

# %%
n, b, _, _ = h1d(dst_full.nS1.values, bins = 10, range = (0,10),
           pltLabels=PlotLabels(x='nS1', y='Entries', title='nS1'))

# %%
fnS1 = n[n.argmax()]/np.sum(n)
print(f'fraction of S1s = {fnS1}')
# Out:
# fraction of S1s = 0.8111041688264021

# %% [markdown]
# #### Fraction of events with 1 S1 is 0.5, due to grass and high energy events. For Krypton select events with 1 S1

# %% [markdown]
# ### Select events with 1 S1

# %%
dst1s1 = dst_full[dst_full.nS1==1]

# %%
n, b, _, _ = h1d(dst1s1.nS2.values, bins = 10, range = (0,10),
           pltLabels=PlotLabels(x='nS2', y='Entries', title='nS2'))

# %% [markdown]
# #### For Krypton select events with only 1 S2

# %%
fnS2 = n[n.argmax()]/np.sum(n)
print(f'fraction of S2s = {fnS2}')
# Out:
# fraction of S2s = 0.96688947613866

# %% [markdown]
# ### Select events with 1 S2

# %%
dst    = dst1s1[dst1s1.nS2==1]

# %%
n_full   = len(dst)
eff = n_full   / ntot 
print(f"Total number of events with 1 s1 and 1 s2 : {n_full}: selection eff = {eff} ")

# vals
summary_vals = open(vals_loc, 'a')
summary_vals.write(f'fracS1={round(fnS1,2)}\n')
summary_vals.write(f'fracS2={round(fnS2,2)}\n')
summary_vals.write(f'fracS1S2={round(eff,2)}\n')
summary_vals.close()
# Out:
# Total number of events with 1 s1 and 1 s2 : 559800: selection eff = 0.7842291215457075

# %% [markdown]
# ### S1 and S2 distributions

# %%
s1d = s1d_from_dst(dst)

# %%
plot_s1histos(dst,  s1d, bins=40, figsize=(10,10))
plt.savefig(summary_outputs+'s1.png')

# %% [markdown]
# ### Fiducial selection in S1

# %% [markdown]
# #### 2 < S1e < 25 pes, which cuts off very low and high energy events

# %%
s1e_range =(3, 25)

# vals
summary_vals = open(vals_loc, 'a')
summary_vals.write(f's1Min={s1e_range[0]}\n')
summary_vals.write(f's1Max={s1e_range[1]}\n')
summary_vals.close()

# %%
dst_s1e    = dst[in_range(dst.S1e, *s1e_range)]

# %%
s1d = s1d_from_dst(dst_s1e, range_s1e = s1e_range)
plot_s1histos(dst_s1e,  s1d, bins=20, figsize=(10,10))

# %%
dst = dst_s1e
s2d = s2d_from_dst(dst)
plot_s2histos(dst, s2d, bins=40, emin=1000, emax=15000, figsize=(10,10))
plt.savefig(summary_outputs+'s2.png')

# %% [markdown]
# ### Fiducial selection in S2

# %%
Nsipm_min = 15 
s2e_range =(3000, 13000)
s2w_range =(5, 15)
s2q_range =(200, 800)

# vals
summary_vals = open(vals_loc, 'a')
summary_vals.write(f's2MinPMT={s2e_range[0]}\n')
summary_vals.write(f's2MaxPMT={s2e_range[1]}\n')
summary_vals.write(f's2MinQ={s2q_range[0]}\n')
summary_vals.write(f's2MaxQ={s2q_range[1]}\n')
summary_vals.write(f'widthMin={s2w_range[0]}\n')
summary_vals.write(f'widthMax={s2w_range[1]}\n')
summary_vals.write(f'numSipmMin={Nsipm_min}\n')
summary_vals.close()

# %%
dst_sipm    = dst[dst.Nsipm >Nsipm_min] 
dst_s2e    = dst_sipm[in_range(dst_sipm.S2e, *s2e_range)] 
dst_s2w    = dst_s2e[in_range(dst_s2e.S2w, *s2w_range)]
dst_s2q    = dst_s2w[in_range(dst_s2w.S2q, *s2q_range)]
dst = dst_s2q

# %%
s2d = s2d_from_dst(dst_s2e)
plot_s2histos(dst, s2d, bins=40, emin=1000, emax=15000, figsize=(10,10))

# %% [markdown]
# ### Time differences in seconds

# %%
dst_time = dst.sort_values('event')
T       = dst_time.time.values
DT      = time_delta_from_time(T)

# %% [markdown]
# ### Define ranges and bins

# %%
krTimes, krRanges, krNbins, krBins = kr_ranges_and_bins(dst,
                                                        xxrange   = (-220,  220),
                                                        yrange    = (-220,  220),
                                                        zrange    = (10,  550),
                                                        s2erange  = s2e_range,
                                                        s1erange  = s1e_range,
                                                        s2qrange  = s2q_range,
                                                        xnbins    = num_xy_bins,
                                                        ynbins    = num_xy_bins,
                                                        znbins    = 50,
                                                        s2enbins  = 50,
                                                        s1enbins  = 50,
                                                        s2qnbins  = 50,
                                                        tpsamples = 3600) # tsamples in seconds

# %% [markdown]
# ### Time
# - Extension in hours of data sample considered

# %%
plt.plot(krTimes.timeStamps)
plt.savefig(summary_outputs+'runTime.png')

# %%
# vals
full_final_datetime = str(krTimes.timeStamps[-1])
final_date = full_final_datetime[:full_final_datetime.find(' ')]

# Once you have the date, find the temperature on that date.
import codecs

data_directory = '/Volumes/NEXT_data/IC_Data/system/'
ctrl = 'SNS'

def itemize(line):
    items = []
    while len(line) > 0:
        if not line.find('\t') == -1:
            potential_item = line[:line.find('\t')]
            potential_item = potential_item.strip()
            if not potential_item == "":
                items.append(potential_item)
            line = line[line.find('\t')+1:]
        elif line.find('\n') == -1:
            items.append(line)
            line = ""
        else:
            line = ""
    return items

vessel_temps = []
param_of_interest = "NEW"

text_path = data_directory + "/" + ctrl + "/" + ctrl + "_Data_Report_" + final_date + ".txt"

data_file = codecs.open(text_path, 'r', encoding='ISO-8859-1')
data_lines = data_file.readlines()

parameters = itemize(data_lines[2])
first_data = itemize(data_lines[3])

for i in range(len(parameters)):
    try:
        print_params = parameters[i]+'='+first_data[i]
        #print(print_params)
    except:
        # print('Failed to find a value for param', [parameters[i]])
        parameters.pop(i)
        i -= 1

for i in range(len(parameters)):
    for j in range(3,len(data_lines)):
        if parameters[i] == param_of_interest:
            itemized = itemize(data_lines[j])
            value = float(itemized[i].replace(',', '.'))
            vessel_temps.append(value)

day_temp = sum(vessel_temps)/(1.0 * len(vessel_temps))
print('The day temp on '+final_date+' was '+str(round(day_temp,1)))

summary_vals = open(vals_loc, 'a')
summary_vals.write('date='+final_date+'\n')
summary_vals.write('labTempC='+str(round(day_temp,1))+'\n')
summary_vals.close()
# Out:
# The day temp on 2019-03-15 was 19.3

# %%
kge = kr_event(dst, DT, dst.S2e, dst.S2q)

# %%
fig = plt.figure(figsize=(10,6))
ax      = fig.add_subplot(1, 1, 1)
(_)    = h1(kge.DT, bins=500, range = (kge.DT[0], kge.DT[-1]), color='red', stats=False, lbl='pre-sel')
plt.savefig(summary_outputs+'runEvt.png')

# %% [markdown]
# ### Control distributions

# %%
nevt = h2d(dst.X, dst.Y, krNbins.X, krNbins.Y, krRanges.X, krRanges.Y, 
           pltLabels=PlotLabels(x='X (mm)', y='Y (mm)', title='X vs Y'),
           profile=False,
           figsize=(10,8))
plt.savefig(summary_outputs+'xy.png')

# %%
nevt = h2d(dst.Z, dst.S1e, krNbins.Z, krNbins.S1e, krRanges.Z, (0,20), 
           pltLabels=PlotLabels(x='Z (mm)', y='S1e (pes)', title='S1 vs Z'),
           profile=False,
           figsize=(10,8))

# %% [markdown]
# #### S1 vs Z distribution:
#
# - Concentrated at low Z: This is due to the fact that gas flow is higher near the anode, and thus there is more krypton near the anode than near the cathode.
# - Increases as a function of Z. The closer to the cathode the larger S1
# - Spread is large: This is due to large variation of solid angle, depending on (X,Y)

# %%
nevt = h2d(dst.Z, dst.S2e, krNbins.Z, krNbins.S1e, krRanges.Z, krRanges.S2e, 
           pltLabels=PlotLabels(x='Z (mm)', y='S2e (pes)', title='S2 vs Z'),
           profile=True,
           figsize=(10,8))

# %% [markdown]
# #### S2 vs Z distribution:
#
# - Concentrated at low Z: This is due to the fact that gas flow is higher near the anode, and thus there is more krypton near the anode than near the cathode.
# - Decreases as a function of Z, due to lifetime
# - Spread is large: This is due to large variation of solid angle, depending on (X,Y)

# %%
nevt = h2d(dst.S1e, dst.S2e, krNbins.S1e, krNbins.S2e, krRanges.S1e, krRanges.S2e, 
           pltLabels=PlotLabels(x='S1e (pes)', y='S2e (pes)', title='S2 vs S1'),
           profile=False,
           figsize=(10,8))

# %% [markdown]
# #### S2 vs S1 distribution:
#
# - Small anti-correlation (more S2 less S1).

# %%
nevt = h2d(dst.S2e, dst.S2q, krNbins.S2e, krNbins.S2q, krRanges.S2e, krRanges.S2q, 
           pltLabels=PlotLabels(x='S2q (pes)', y='S2e (pes)', title='S2q vs S2e'),
           profile=False,
           figsize=(10,8))

# %% [markdown]
# #### S2 vs Q distribution:
#
# - Clear correlation between S2 and Q

# %% [markdown]
# ### Select central region in R

# %% [markdown]
# #### The effect is to reduce the dependence of geometrical corrections

# %%
dst_R     = dst[dst.R < 100]

# %%
plot_energy_distributions(dst_R, krBins.Z, krBins.S1e, krBins.S2e, krBins.S2q, figsize=(14,12))
plt.savefig(summary_outputs+'s1s2q.png')

# %% [markdown]
# ### Select central region in Z
#
# - The effect is to reduce the dependence of lifetime

# %%
dst_core     = dst_R[dst_R.Z < 200]

# %% [markdown]
# ### Energy in core

# %%
(_) = h1d(dst_core.S2e, bins = 50, range =(3000,14000), legendloc='upper left')

# %% [markdown]
# ### Apply bootstrap corrections.
#
# - One can correct S2e and S2q by geometrical corrections using an existing map (a bootstrap map). This has the effect to reduce the geometrical dependence on both distributions, permitting an additional filtering

# %%
kre = kr_event(dst)

# %%
bootstrap_correction_filename = os.path.expandvars(bootstrap_correction_filename)
calibrate = corrections.Calibration(bootstrap_correction_filename)
E, Q = calibrate(kre.X, kre.Y, None, kre.T, kre.S2e, kre.S2q)

# %%
kge = kr_event(dst, DT, E, Q)

# %%
(_) = h1d(kge.E, bins = 50, range =(3000,12000))

# %% [markdown]
# #### Plot of E and Q corrected vs Z shows much less spread (XY corrections applied only remaining LT corrections)

# %%
nevt = h2d(dst.Z, E, krNbins.Z, krNbins.S2e, krRanges.Z, krRanges.S2e, 
           pltLabels=PlotLabels(x='Z', y='E corrected', title='E corrected vs Z'),
           profile=True,
           figsize=(10,6))

# %%
nevt = h2d(dst.Z, Q, krNbins.Z, krNbins.S2q, krRanges.Z, krRanges.S2q, 
           pltLabels=PlotLabels(x='Z', y='Q corrected', title='Q corrected vs Z'),
           profile=True,
           figsize=(10,6))

# %% [markdown]
# ### Filter

# %%
range_krs2 = (7e+3,12e+3)

# %%
num_bins = 50
num_in_band = 0
while num_in_band == 0 and num_bins >= 5:
    sel_krband, fpl, fph, hp, pp = selection_in_band(kre.Z, E,
                                                     range_z = krRanges.Z,
                                                     range_e = range_krs2,
                                                     nbins_z = num_bins,
                                                     nbins_e = num_bins,
                                                     nsigma  = 3.5)
    readout = selection_info(sel_krband, 'Kr band')
    readout = readout[readout.find(': ')+2:]
    readout = readout[:readout.find(' ')]
    num_in_band = int(readout)
    num_bins -= 1
print('Final number of bins =', num_bins)
# Out:
# Total number of selected candidates Kr band: 469268 (94.7 %)
# Final number of bins = 49
# /Users/jmhaefner/Development/KryptonCalibration/KrCalibTEMP/ICAROS/krcal/core/fit_functions.py:45: UserWarning: nof = 0 in chi2 calculation, return chi2 = {chi2_}
#   warnings.warn('nof = 0 in chi2 calculation, return chi2 = {chi2_}', UserWarning)
# /Users/jmhaefner/Development/KryptonCalibration/KrCalibTEMP/ICAROS/krcal/core/fit_functions.py:45: UserWarning: nof = 0 in chi2 calculation, return chi2 = {chi2_}
#   warnings.warn('nof = 0 in chi2 calculation, return chi2 = {chi2_}', UserWarning)

# %%
plot_selection_in_band(fpl, fph, hp, pp)

# %%
selection_info(sel_krband, 'Kr band')
# Out:
# Total number of selected candidates Kr band: 469268 (94.7 %)
# 'Total number of selected candidates Kr band: 469268 (94.7 %)'

# %%
kges = kr_event(dst, DT, E, Q, sel_mask=sel_krband)

# %% [markdown]
# ### Energy before and after filter

# %%
fig = plt.figure(figsize=(12,6))
ax      = fig.add_subplot(1, 2, 1)
(_)     = h1(kge.E,  bins = 50, range =(3000,12000))
plot_histo(PlotLabels('E (pes)','Entries','Pre-filter'), ax, legendloc='upper left')
ax      = fig.add_subplot(1, 2, 2)
(_)     = h1(kges.E,  bins = 50, range =(3000,12000))
plot_histo(PlotLabels('E (pes)','Entries','Post-filter'), ax, legendloc='upper left')
plt.tight_layout()

# %%
nevt = h2d(kges.Z, kges.E, krNbins.Z, krNbins.S2e, krRanges.Z, krRanges.S2e, 
           pltLabels=PlotLabels(x='Z', y='E corrected', title='E corrected vs Z post filter'),
           profile=True,
           figsize=(10,6))

# %%
nevt = h2d(kges.Z, kges.Q, krNbins.Z, krNbins.S2q, krRanges.Z, krRanges.S2q, 
           pltLabels=PlotLabels(x='Z', y='Q corrected', title='Q corrected vs Z post-filter'),
           profile=True,
           figsize=(10,6))

# %% [markdown]
# #### Notice how the filter cleans up the energy distributions.

# %% [markdown]
# ### Time evolution

# %%
fig = plt.figure(figsize=(10,6))
ax      = fig.add_subplot(1, 1, 1)
(_)    = h1(kge.T, bins=500, range = (kge.T.min(), kge.T.max()), color='red', stats=False, lbl='pre-sel')
plot_histo(PlotLabels('Time','Entries',''), ax)
(_)    = h1(kges.T, bins=500, range = (kges.T.min(), kges.T.max()), color='blue',stats=False, lbl='post-sel')
plot_histo(PlotLabels('Time','Entries',''), ax)

# %% [markdown]
# #### event density is constant, indicating a stable run

# %% [markdown]
# ### S1 and Corrected E and Q as a function of T

# %%
nevt = h2d(kges.T, kges.S1e, krNbins.T, krNbins.S1e, krRanges.T, krRanges.S1e, 
           pltLabels=PlotLabels(x='T', y='S1 corrected', title='S1 vs T post-filter'),
           profile=True,
           figsize=(10,6))

# %%
nevt = h2d(kges.T, kges.E, krNbins.T, krNbins.S2e, krRanges.T, krRanges.S2e, 
           pltLabels=PlotLabels(x='T', y='E corrected', title='E corrected vs T post-filter'),
           profile=True,
           figsize=(10,6))

# %%
nevt = h2d(kges.T, kges.Q, krNbins.T, krNbins.S2q, krRanges.T, krRanges.S2q, 
           pltLabels=PlotLabels(x='T', y='Q corrected', title='Q corrected vs T post-filter'),
           profile=True,
           figsize=(10,6))

# %% [markdown]
# ### All amplitudes are constant as a function of time in an stable run

# %% [markdown]
# ### Select dst

# %%
dsts = dst[sel_krband]

# %% [markdown]
# ### X vs Y again

# %%
nevt = h2d(dsts.X, dsts.Y, krNbins.X, krNbins.Y, krRanges.X, krRanges.Y, 
           pltLabels=PlotLabels(x='X (mm)', y='Y (mm)', title='X vs Y post-filter'),
           profile=False,
           figsize=(10,8))

# %% [markdown]
# ### Spatial distributions

# %% [markdown]
# #### In R and Z

# %%
fig = plt.figure(figsize=(14,6))
ax      = fig.add_subplot(1, 2, 1)
(_)    = h1(kge.R, bins=50, range = (0,200), color='red', stats=False, lbl='pre-sel')
plot_histo(PlotLabels('R','Entries',''), ax)
(_)   = h1(kges.R, bins=50, range = (0,200), color='blue',stats=False, lbl='post-sel')
plot_histo(PlotLabels('R','Entries',''), ax)
ax      = fig.add_subplot(1, 2, 2)
(_)    = h1(kge.Z, bins=50, range = (0,550), color='red', stats=False, lbl='pre-sel')
plot_histo(PlotLabels('Z','Entries',''), ax)
(_)    = h1(kges.Z, bins=50, range = (0,550), color='blue',stats=False, lbl='post-sel')
plot_histo(PlotLabels('Z','Entries',''), ax)
plt.tight_layout()

# %% [markdown]
# #### In X Y

# %%
fig = plt.figure(figsize=(14,6))
ax      = fig.add_subplot(1, 2, 1)
(_)    = h1(kge.X, bins=50, range = (-200,200), color='red', stats=False, lbl='pre-sel')
plot_histo(PlotLabels('X','Entries',''), ax)
(_)    = h1(kges.X, bins=50, range = (-200,200), color='blue',stats=False, lbl='post-sel')
plot_histo(PlotLabels('X','Entries',''), ax)
ax      = fig.add_subplot(1, 2, 2)
(_)    = h1(kge.Y, bins=50, range = (-200,200), color='red', stats=False, lbl='pre-sel')
plot_histo(PlotLabels('X','Entries',''), ax)
(_)    = h1(kges.Y, bins=50, range = (-200,200), color='blue',stats=False, lbl='post-sel')
plot_histo(PlotLabels('Y','Entries',''), ax)
plt.tight_layout()

# %% [markdown]
# ### Charge and SiPM distributions

# %%
fig = plt.figure(figsize=(14,6))
ax      = fig.add_subplot(1, 2, 1)
(_)    = h1(kge.Q, bins=50, range = (0,800), color='red', stats=False, lbl='pre-sel')
plot_histo(PlotLabels('Qg','Entries',''), ax)
(_)    = h1(kges.Q, bins=50, range = (0,800), color='blue',stats=False, lbl='post-sel')
plot_histo(PlotLabels('Qg','Entries',''), ax)
ax      = fig.add_subplot(1, 2, 2)
(_)    = h1(dst.Nsipm, bins=50, range = (0,50), color='red', stats=False, lbl='pre-sel')
plot_histo(PlotLabels('Nsipm','Entries',''), ax)
(_)    = h1(dsts.Nsipm, bins=50, range = (0,50), color='blue',stats=False, lbl='post-sel')
plot_histo(PlotLabels('Nsipm','Entries',''), ax)
plt.tight_layout()

# %% [markdown]
# ### Write DST (merged and fiducial)

# %%
dst.columns
# Out:
# Index(['event', 'time', 's1_peak', 's2_peak', 'nS1', 'nS2', 'S1w', 'S1h',
#        'S1e', 'S1t', 'S2w', 'S2h', 'S2e', 'S2q', 'S2t', 'Nsipm', 'DT', 'Z',
#        'Zrms', 'X', 'Y', 'R', 'Phi', 'Xrms', 'Yrms'],
#       dtype='object')

# %%
#del dst['index']
print('Time after loading to before writing =', round(time.time() - last_time))
last_time = time.time()
# Out:
# Time after loading to before writing = 33

# %%
if (write_filtered_dst):
    print('writing filtered dst ', output_dst_filename)
    kdst_write(dsts, output_dst_filename);
print('Time to write =', round(time.time() - last_time))
print('Full notebook time =', round(time.time() - t0))
# Out:
# writing filtered dst  /Volumes/NEXT_data/IC_Data//dst/dst_7006_trigger1_0000_2836.h5
# Time to write = 39
# Full notebook time = 149

# %% [markdown]
# ## End of NB
