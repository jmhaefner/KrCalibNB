# %% [markdown]
# # Krypton Lifetime maps

# %% [markdown]
# ### Author:  JJGC

# %% [markdown]
# ### Software: KrCalib : https://github.com/nextic/KrCalib/

# %%
# %load_ext autoreload
# %autoreload 2
import os
import sys
import time
import warnings
import datetime 
print("Last updated on ", time.asctime())
# Out:
# Last updated on  Tue Jan 22 08:59:40 2019

# %% [markdown]
# ### Logger

# %%
import logging


logging.basicConfig(format='%(asctime)s | %(levelname)s : %(message)s',
                     level=logging.INFO, stream=sys.stdout)

logging.info('Hello world!')
# Out:
# 2019-01-22 08:59:40,848 | INFO : Hello world!

# %% [markdown]
# ### Input files

# %%
from krcal.core.kr_types import KrFileName

run_number = 6803
# run_number = 6340 # for testing only
t_start = time.time()

lifetime_limits = (2350, 5150)
e0_limits = (7000, 14000)
e0_limits_rphi = (12000, 14000)

input_path  = f"$IC_DATA/dst"
output_path = f"$IC_DATA/ldst"
output_plots = f"$IC_DATA/plots"
output_plots = os.path.expandvars(f"{output_plots}/")
summary_outputs = "/Users/jmhaefner/Development/KryptonCalibration/KrCalibNB_JMH/KrCalibNB/doc/img/r"+str(run_number)+"/"
map_path    = f"$IC_DATA/maps"

# Find the name of the correct input dst

dst_directory = os.path.expandvars(f"{input_path}/")
dirlist = os.listdir(dst_directory)
dst_file = ""
for file_name in dirlist:
    try:
        check_number = file_name
        check_number = check_number[check_number.find('_')+1:]
        check_number = check_number[:check_number.find('_')]
        if check_number == str(run_number):
            print('Found the dst:',file_name)
            dst_file = file_name
    except:
        pass

if dst_file == "":
    raise ValueError("Unable to find appropriate dst for run "+str(run_number))

input_file_names  = [ dst_file ]

    
time_bins = 25
output_file_name  = ' '
map_file_name     = 'kr_maps_xy_'+str(run_number)+'.h5'
map_file_name_ts  = f'kr_maps_rphi_5_8_ts_{time_bins}_'+str(run_number)+'.h5'
emap_file_name    = 'kr_emap_xy_50_50_r_'+str(run_number)+'.h5'


krfn = KrFileName(input_file_names,
                  output_file_name,
                  map_file_name,
                  map_file_name_ts,
                  emap_file_name)
# Out:
# Found the dst: dst_6803_trigger1_0000_5162.h5

# %% [markdown]
# ### Notebook configuration

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

from matplotlib.patches import Circle, Wedge, Polygon
from matplotlib.collections import PatchCollection

plt.rcParams["figure.figsize"] = 10, 8
plt.rcParams["font.size"     ] = 14

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib
import tables            as tb
import random
import glob
import warnings
sns.set()

# %%
from  invisible_cities.io.dst_io              import load_dsts
from  invisible_cities.core .core_functions   import in_range
import invisible_cities.reco.corrections      as corrf

# %%
from krcal.core.io_functions       import kdst_write
from krcal.core.io_functions       import filenames_from_list
from krcal.core.io_functions       import write_maps
from krcal.core.io_functions       import read_maps
from krcal.core.io_functions       import write_maps_ts
from krcal.core.io_functions       import read_maps_ts

# %%
from krcal.core.histo_functions    import h1, h1d, h2, h2d, plot_histo

# %%
from krcal.core.core_functions      import time_delta_from_time
from krcal.core.core_functions      import phirad_to_deg
from krcal.core.core_functions      import timeit
from krcal.core.core_functions      import NN
from krcal.core                     import fit_functions_ic as fitf

# %%
from krcal.core.plt_functions  import plot_sector
from krcal.core.plt_functions  import plot_sectors

# %%
from krcal.core.stat_functions      import mean_and_std

# %%
from krcal.core.analysis_functions  import kr_ranges_and_bins
from krcal.core.analysis_functions  import fiducial_volumes
from krcal.core.analysis_functions  import fid_eff
from krcal.core.analysis_functions  import select_rphi_sectors
from krcal.core.analysis_functions  import select_xy_sectors
from krcal.core.analysis_functions  import event_map

from krcal.core.analysis_functions  import kr_event_selection
from krcal.core.analysis_functions  import kr_event

# %%
from krcal.core.fit_lt_functions    import fit_lifetime
from krcal.core.fit_lt_functions    import time_fcs
from krcal.core.fit_lt_functions    import fit_fcs_in_rphi_sectors
from krcal.core.fit_lt_functions    import fit_fcs_in_xy_bin
from krcal.core.fit_lt_functions    import fit_map_rphi
from krcal.core.fit_lt_functions    import fit_map_xy
from krcal.core.fit_lt_functions    import get_time_series

# %%
from krcal.core.fit_lt_histograms   import histo_fit_sectors
from krcal.core.fit_lt_histograms   import print_fit_sectors_pars
from krcal.core.fit_lt_histograms   import plot_fit_sectors
from krcal.core.fit_lt_histograms   import plot_fit_xy
from krcal.core.fit_lt_histograms   import plot_time_fcs
from krcal.core.fit_lt_histograms   import plot_fit_lifetime_and_chi2
from krcal.core.fit_lt_histograms   import print_fit_lifetime

# %%
from krcal.core.fit_energy_functions    import fit_energy
from krcal.core.fit_energy_functions    import plot_fit_energy
from krcal.core.fit_energy_functions    import print_fit_energy
from krcal.core.fit_energy_functions    import resolution_r_z
from krcal.core.fit_energy_functions    import plot_resolution_r_z

# %%
from krcal.core.kr_types import PlotLabels, KrEvent, ASectorMap
from krcal.core.kr_types import FitType, KrSector, MapType
from krcal.core.kr_types import KrFileName

# %%
from krcal.core.rphi_maps_functions   import draw_rphi_maps
from krcal.core.rphi_maps_functions   import draw_rphi_map
from krcal.core.rphi_maps_functions   import draw_rphi_maps_ts
from krcal.core.rphi_maps_functions   import draw_wedges
from krcal.core.rphi_maps_functions   import define_rphi_sectors
from krcal.core.rphi_maps_functions   import rphi_sector_map_def

# %%
from krcal.core.map_functions   import tsmap_from_fmap
from krcal.core.map_functions   import amap_from_tsmap
from krcal.core.map_functions   import relative_errors
from krcal.core.map_functions   import amap_valid_mask
from krcal.core.map_functions   import amap_valid_fraction
from krcal.core.map_functions   import amap_average
from krcal.core.map_functions   import amap_max
from krcal.core.map_functions   import amap_min
from krcal.core.map_functions   import amap_replace_nan_by_mean
from krcal.core.map_functions   import amap_replace_nan_by_zero
from krcal.core.map_functions   import regularize_maps
from krcal.core.map_functions   import get_maps_from_tsmap
from krcal.core.map_functions   import map_average

# %%
from krcal.core.xy_maps_functions   import draw_xy_maps
from krcal.core.xy_maps_functions   import draw_xy_map
from krcal.core.xy_maps_functions   import draw_xy_maps_ts

# %%
from krcal.core.s1s2_functions  import energy_time_profile
from krcal.core.s1s2_functions  import energy_X_profile

# %%
from krcal.core.correction_functions import e0_rphi_correction
from krcal.core.correction_functions import e0_xy_correction
from krcal.core.correction_functions import lt_xy_correction
from krcal.core.correction_functions import e0_xy_correction_ts
from krcal.core.correction_functions import lt_xy_correction_ts
from krcal.core.correction_functions import lt_rphi_correction
from krcal.core.correction_functions import lt_rphi_correction_ts
from krcal.core.correction_functions import e0_rphi_correction_ts

# %%
from numpy import pi, sqrt

# %%
from typing      import List, Tuple, Dict, Sequence, Iterable

# %%
from ipywidgets import interact, interactive, fixed
from IPython.display import display

# %% [markdown]
# ### Logger
#
#
# - CRITICAL
# - ERROR
# - WARNING
# - INFO
# - DEBUG

# %%
log = logging.getLogger()

# %% [markdown]
# ### Input/output

# %%
fn =filenames_from_list(krfn, input_path, output_path, map_path)

# %%
t0 = time.time()
dst           = load_dsts(fn.input_file_names, "DST", "Events")
t1 = time.time()
print(f'Read in file time: t = {t1 -t0}')
# Out:
# Read in file time: t = 1.6431190967559814

# %%
unique_events = ~dst.event.duplicated()
number_of_evts_full = np.count_nonzero(unique_events)

print(f"Total number of events: {len(dst)}")
# Out:
# Total number of events: 215709

# %%
dst.columns
# Out:
# Index(['index', 'event', 'time', 's1_peak', 's2_peak', 'nS1', 'nS2', 'S1w',
#        'S1h', 'S1e', 'S1t', 'S2w', 'S2h', 'S2e', 'S2q', 'S2t', 'Nsipm', 'DT',
#        'Z', 'Zrms', 'X', 'Y', 'R', 'Phi', 'Xrms', 'Yrms'],
#       dtype='object')

# %% [markdown]
# ### Time differences in seconds

# %%
dst_time = dst.sort_values('time')
T       = dst_time.time.values
DT      = time_delta_from_time(T)

# %% [markdown]
# ### Ranges and binning

# %%
RMAX      = 200
RCORE     = 100
s1e_range = (3, 25)
s2e_range = (2000, 14000)
s2q_range = (200, 800)

xy_range  = (-RMAX,  RMAX)
z_range   = (10,  550)
e_range = (5000, 14000)
lt_range = (1000, 6000)
c2_range = (0,5)

krTimes, krRanges, krNbins, krBins = kr_ranges_and_bins(dst,
                                                        xxrange   = xy_range,
                                                        yrange    = xy_range,
                                                        zrange    = z_range,
                                                        s2erange  = s2e_range,
                                                        s1erange  = s1e_range,
                                                        s2qrange  = s2q_range,
                                                        xnbins    = 100,
                                                        ynbins    = 100,
                                                        znbins    = 15,
                                                        s2enbins  = 25,
                                                        s1enbins  = 10,
                                                        s2qnbins  = 25,
                                                        tpsamples = 3600) # tsamples in seconds

# %%
dst = dst[in_range(dst.R, 0, RMAX)]

# %%
dst_time = dst.sort_values('time')
T       = dst_time.time.values
DT      = time_delta_from_time(T)
plt.plot(DT)
plt.show()
plt.plot(T)
plt.show()

# %%
kge = kr_event(dst, DT, dst.S2e, dst.S2q)

# %%
fig = plt.figure(figsize=(10,6))
ax      = fig.add_subplot(1, 1, 1)
(_)    = h1(kge.DT, bins=500, range = (kge.DT[0], kge.DT[-1]), color='red', stats=False, lbl='pre-sel')

# %% [markdown]
# ### Time

# %%
plt.plot(krTimes.timeStamps)

# %% [markdown]
# ### Event distribution

# %%
nevt = h2d(dst.X, dst.Y, krNbins.X, krNbins.Y, krRanges.X, krRanges.Y, 
           pltLabels=PlotLabels(x='X (mm)', y='Y (mm)', title='X vs Y '+str(run_number)),
           profile=False,
           figsize=(10,8))
plt.savefig(output_plots+'/EventDists/EventDist_'+str(run_number)+'.png')

# %% [markdown]
# ## Time series

# %%
log.setLevel(logging.INFO)

# %% [markdown]
# ### Divide dst in 100 time series

# %%
time_bins = 25
t0 = time.time()

ts, masks = get_time_series(time_bins, (DT[0],DT[-1]), kge)
t1 = time.time()
print(f' get_time_series: t = {t1 -t0}')
# Out:
#  get_time_series: t = 0.01058197021484375

# %% [markdown]
# ### Fit lifetime full detector

# %%
t0 = time.time()
fps = time_fcs(ts, masks, kge, 
               nbins_z = 15,
               nbins_e = 25,
               range_z = (10, 550),
               range_e = (7000, 14000),
               energy  = 'S2e',
               fit     = FitType.profile) # lifetime fit parameter time series
t1 = time.time()
print(f' time_fcs: t = {t1 -t0}')
# Out:
#  time_fcs: t = 0.17755794525146484

# %%
plot_time_fcs(fps,
              range_chi2  = (0,20),
              range_e0    = (10000,10400),
              range_lt    = (4000, 6000),
              figsize     = (12,6))

# %% [markdown]
# ## Lifetime in RPhi

# %%
NSECTORS =5  # number of sectors in R. Each sector then is 200 / 5 = 40 cm.
SPHI     =45 # size of the phi pie-slice in degrees, thus 10 slices in phi.
#NSECTORS =4  # number of sectors in R. Each sector then is 200 / 5 = 40 cm.
#SPHI     =45 # size of the phi pie-slice in degrees, thus 10 slices in phi.

# %%
rpsmd = rphi_sector_map_def(nSectors=NSECTORS, rmax=RMAX, sphi=SPHI)

# %%
W = define_rphi_sectors(rpsmd)

# %%
draw_wedges(W,  rmax = RMAX, 
            scale= 0.49, figsize=(10,8), alpha=1.0,
            cr =range(NSECTORS))

# %%
t0 = time.time()
KSRP = select_rphi_sectors(dst, DT, dst.S2e, dst.S2q, W)
t1 = time.time()
print(f' KRES: t = {t1 -t0}')
# Out:
#  KRES: t = 0.44091200828552246

# %%
neM = event_map(KSRP)

# %%
neM
# Out:
#       0     1     2     3      4
# 0  1071  3439  5652  8198   9874
# 1  1108  3206  5738  8693  10183
# 2  1088  3181  5563  8454   9762
# 3  1009  3210  5282  7756   9376
# 4  1059  3022  5299  6619   8621
# 5  1099  3230  5127  7488   7627
# 6  1191  3395  5889  8244   8326
# 7  1023  3217  5791  7788   9048

# %%
ax = sns.heatmap(neM, square=True)

# %% [markdown]
# ### four phi sectors: upper half (left-right), lower half (left-right) of chamber

# %% [markdown]
# ### R < 40 mm

# %%
erange = (0,14500)
ltrange = (0, 7000)

# %%
for sector in range(NSECTORS):
    fps = fit_fcs_in_rphi_sectors(sector = sector,
                              selection_map = KSRP,
                              event_map     = neM,
                              n_time_bins   = time_bins,
                              time_diffs    = DT,
                              nbins_z       = 25,
                              nbins_e       = 50,
                              range_z       =(50, 550),
                              range_e       = (5000, 14500),
                              energy        = 'S2e',
                              fit           = FitType.unbined,
                              n_min         = 100)
    plot_fit_sectors(fps,  range_e0 =erange, range_lt=ltrange)
    plt.savefig(summary_outputs+'R_phi_lt'+str(sector+1)+'.png')

# %% [markdown]
# ### Lifetime patterns:
#
# - Oscillatory pattern in time with a swing of 1 ms!
# - Lifetime changes also as a function of Phi, with differences that increase as R increases.
# - R > 160 cm data shows very high and very variable lifetime, with a spread of several ms.

# %% [markdown]
# ### Strategy
#
# - Try to correct geometrical effects first. Fine grained geometrical map with a single time bin.
# - Study time dependence later

# %% [markdown]
# ## Divide chamber in sectors of XY

# %%
log.setLevel(logging.DEBUG)

# %%
t0 = time.time()
print(len(dst))
print(len(DT))
KRES = select_xy_sectors(dst, DT, dst.S2e.values, dst.S2q.values, krBins.X, krBins.Y)
t1 = time.time()
print(f' KRES: t = {t1 -t0}')
# Out:
# 214946
# 214946
# 2019-01-22 09:00:03,749 | DEBUG :  function: select_xy_sectors
# 2019-01-22 09:00:03,750 | DEBUG :  calling selection_mask
# 2019-01-22 09:00:03,754 | DEBUG : computing selection mask for sector 0
# 2019-01-22 09:00:03,880 | DEBUG : computing selection mask for sector 1
# 2019-01-22 09:00:03,970 | DEBUG : computing selection mask for sector 2
# 2019-01-22 09:00:04,072 | DEBUG : computing selection mask for sector 3
# 2019-01-22 09:00:04,160 | DEBUG : computing selection mask for sector 4
# 2019-01-22 09:00:04,251 | DEBUG : computing selection mask for sector 5
# 2019-01-22 09:00:04,341 | DEBUG : computing selection mask for sector 6
# 2019-01-22 09:00:04,426 | DEBUG : computing selection mask for sector 7
# 2019-01-22 09:00:04,513 | DEBUG : computing selection mask for sector 8
# 2019-01-22 09:00:04,596 | DEBUG : computing selection mask for sector 9
# 2019-01-22 09:00:04,678 | DEBUG : computing selection mask for sector 10
# 2019-01-22 09:00:04,764 | DEBUG : computing selection mask for sector 11
# 2019-01-22 09:00:04,893 | DEBUG : computing selection mask for sector 12
# 2019-01-22 09:00:05,034 | DEBUG : computing selection mask for sector 13
# 2019-01-22 09:00:05,132 | DEBUG : computing selection mask for sector 14
# 2019-01-22 09:00:05,218 | DEBUG : computing selection mask for sector 15
# 2019-01-22 09:00:05,304 | DEBUG : computing selection mask for sector 16
# 2019-01-22 09:00:05,395 | DEBUG : computing selection mask for sector 17
# 2019-01-22 09:00:05,480 | DEBUG : computing selection mask for sector 18
# 2019-01-22 09:00:05,569 | DEBUG : computing selection mask for sector 19
# 2019-01-22 09:00:05,648 | DEBUG : computing selection mask for sector 20
# 2019-01-22 09:00:05,728 | DEBUG : computing selection mask for sector 21
# 2019-01-22 09:00:05,809 | DEBUG : computing selection mask for sector 22
# 2019-01-22 09:00:05,895 | DEBUG : computing selection mask for sector 23
# 2019-01-22 09:00:05,979 | DEBUG : computing selection mask for sector 24
# 2019-01-22 09:00:06,068 | DEBUG : computing selection mask for sector 25
# 2019-01-22 09:00:06,164 | DEBUG : computing selection mask for sector 26
# 2019-01-22 09:00:06,266 | DEBUG : computing selection mask for sector 27
# 2019-01-22 09:00:06,368 | DEBUG : computing selection mask for sector 28
# 2019-01-22 09:00:06,472 | DEBUG : computing selection mask for sector 29
# 2019-01-22 09:00:06,559 | DEBUG : computing selection mask for sector 30
# 2019-01-22 09:00:06,647 | DEBUG : computing selection mask for sector 31
# 2019-01-22 09:00:06,724 | DEBUG : computing selection mask for sector 32
# 2019-01-22 09:00:06,810 | DEBUG : computing selection mask for sector 33
# 2019-01-22 09:00:06,890 | DEBUG : computing selection mask for sector 34
# 2019-01-22 09:00:06,985 | DEBUG : computing selection mask for sector 35
# 2019-01-22 09:00:07,084 | DEBUG : computing selection mask for sector 36
# 2019-01-22 09:00:07,198 | DEBUG : computing selection mask for sector 37
# 2019-01-22 09:00:07,291 | DEBUG : computing selection mask for sector 38
# 2019-01-22 09:00:07,374 | DEBUG : computing selection mask for sector 39
# 2019-01-22 09:00:07,454 | DEBUG : computing selection mask for sector 40
# 2019-01-22 09:00:07,536 | DEBUG : computing selection mask for sector 41
# 2019-01-22 09:00:07,618 | DEBUG : computing selection mask for sector 42
# 2019-01-22 09:00:07,702 | DEBUG : computing selection mask for sector 43
# 2019-01-22 09:00:07,784 | DEBUG : computing selection mask for sector 44
# 2019-01-22 09:00:07,872 | DEBUG : computing selection mask for sector 45
# 2019-01-22 09:00:07,967 | DEBUG : computing selection mask for sector 46
# 2019-01-22 09:00:08,057 | DEBUG : computing selection mask for sector 47
# 2019-01-22 09:00:08,169 | DEBUG : computing selection mask for sector 48
# 2019-01-22 09:00:08,248 | DEBUG : computing selection mask for sector 49
# 2019-01-22 09:00:08,334 | DEBUG : computing selection mask for sector 50
# 2019-01-22 09:00:08,422 | DEBUG : computing selection mask for sector 51
# 2019-01-22 09:00:08,513 | DEBUG : computing selection mask for sector 52
# 2019-01-22 09:00:08,611 | DEBUG : computing selection mask for sector 53
# 2019-01-22 09:00:08,689 | DEBUG : computing selection mask for sector 54
# 2019-01-22 09:00:08,768 | DEBUG : computing selection mask for sector 55
# 2019-01-22 09:00:08,856 | DEBUG : computing selection mask for sector 56
# 2019-01-22 09:00:08,950 | DEBUG : computing selection mask for sector 57
# 2019-01-22 09:00:09,032 | DEBUG : computing selection mask for sector 58
# 2019-01-22 09:00:09,119 | DEBUG : computing selection mask for sector 59
# 2019-01-22 09:00:09,208 | DEBUG : computing selection mask for sector 60
# 2019-01-22 09:00:09,294 | DEBUG : computing selection mask for sector 61
# 2019-01-22 09:00:09,392 | DEBUG : computing selection mask for sector 62
# 2019-01-22 09:00:09,509 | DEBUG : computing selection mask for sector 63
# 2019-01-22 09:00:09,599 | DEBUG : computing selection mask for sector 64
# 2019-01-22 09:00:09,689 | DEBUG : computing selection mask for sector 65
# 2019-01-22 09:00:09,773 | DEBUG : computing selection mask for sector 66
# 2019-01-22 09:00:09,865 | DEBUG : computing selection mask for sector 67
# 2019-01-22 09:00:09,955 | DEBUG : computing selection mask for sector 68
# 2019-01-22 09:00:10,039 | DEBUG : computing selection mask for sector 69
# 2019-01-22 09:00:10,127 | DEBUG : computing selection mask for sector 70
# 2019-01-22 09:00:10,218 | DEBUG : computing selection mask for sector 71
# 2019-01-22 09:00:10,305 | DEBUG : computing selection mask for sector 72
# 2019-01-22 09:00:10,388 | DEBUG : computing selection mask for sector 73
# 2019-01-22 09:00:10,468 | DEBUG : computing selection mask for sector 74
# 2019-01-22 09:00:10,548 | DEBUG : computing selection mask for sector 75
# 2019-01-22 09:00:10,625 | DEBUG : computing selection mask for sector 76
# 2019-01-22 09:00:10,708 | DEBUG : computing selection mask for sector 77
# 2019-01-22 09:00:10,794 | DEBUG : computing selection mask for sector 78
# 2019-01-22 09:00:10,876 | DEBUG : computing selection mask for sector 79
# 2019-01-22 09:00:10,959 | DEBUG : computing selection mask for sector 80
# 2019-01-22 09:00:11,057 | DEBUG : computing selection mask for sector 81
# 2019-01-22 09:00:11,149 | DEBUG : computing selection mask for sector 82
# 2019-01-22 09:00:11,242 | DEBUG : computing selection mask for sector 83
# 2019-01-22 09:00:11,328 | DEBUG : computing selection mask for sector 84
# 2019-01-22 09:00:11,413 | DEBUG : computing selection mask for sector 85
# 2019-01-22 09:00:11,500 | DEBUG : computing selection mask for sector 86
# 2019-01-22 09:00:11,585 | DEBUG : computing selection mask for sector 87
# 2019-01-22 09:00:11,669 | DEBUG : computing selection mask for sector 88
# 2019-01-22 09:00:11,753 | DEBUG : computing selection mask for sector 89
# 2019-01-22 09:00:11,854 | DEBUG : computing selection mask for sector 90
# 2019-01-22 09:00:11,945 | DEBUG : computing selection mask for sector 91
# 2019-01-22 09:00:12,029 | DEBUG : computing selection mask for sector 92
# 2019-01-22 09:00:12,118 | DEBUG : computing selection mask for sector 93
# 2019-01-22 09:00:12,198 | DEBUG : computing selection mask for sector 94
# 2019-01-22 09:00:12,278 | DEBUG : computing selection mask for sector 95
# 2019-01-22 09:00:12,364 | DEBUG : computing selection mask for sector 96
# 2019-01-22 09:00:12,441 | DEBUG : computing selection mask for sector 97
# 2019-01-22 09:00:12,519 | DEBUG : computing selection mask for sector 98
# 2019-01-22 09:00:12,599 | DEBUG : computing selection mask for sector 99
# 2019-01-22 09:00:12,680 | DEBUG :  selection mask computed, filling selections
# 2019-01-22 09:00:12,681 | DEBUG :  defining kr_event for sector 0
# 2019-01-22 09:00:12,771 | DEBUG :  defining kr_event for sector 1
# 2019-01-22 09:00:12,875 | DEBUG :  defining kr_event for sector 2
# 2019-01-22 09:00:12,974 | DEBUG :  defining kr_event for sector 3
# 2019-01-22 09:00:13,063 | DEBUG :  defining kr_event for sector 4
# 2019-01-22 09:00:13,163 | DEBUG :  defining kr_event for sector 5
# 2019-01-22 09:00:13,266 | DEBUG :  defining kr_event for sector 6
# 2019-01-22 09:00:13,375 | DEBUG :  defining kr_event for sector 7
# 2019-01-22 09:00:13,461 | DEBUG :  defining kr_event for sector 8
# 2019-01-22 09:00:13,548 | DEBUG :  defining kr_event for sector 9
# 2019-01-22 09:00:13,638 | DEBUG :  defining kr_event for sector 10
# 2019-01-22 09:00:13,726 | DEBUG :  defining kr_event for sector 11
# 2019-01-22 09:00:13,821 | DEBUG :  defining kr_event for sector 12
# 2019-01-22 09:00:13,914 | DEBUG :  defining kr_event for sector 13
# 2019-01-22 09:00:14,009 | DEBUG :  defining kr_event for sector 14
# 2019-01-22 09:00:14,103 | DEBUG :  defining kr_event for sector 15
# 2019-01-22 09:00:14,195 | DEBUG :  defining kr_event for sector 16
# 2019-01-22 09:00:14,292 | DEBUG :  defining kr_event for sector 17
# 2019-01-22 09:00:14,387 | DEBUG :  defining kr_event for sector 18
# 2019-01-22 09:00:14,481 | DEBUG :  defining kr_event for sector 19
# 2019-01-22 09:00:14,591 | DEBUG :  defining kr_event for sector 20
# 2019-01-22 09:00:14,688 | DEBUG :  defining kr_event for sector 21
# 2019-01-22 09:00:14,787 | DEBUG :  defining kr_event for sector 22
# 2019-01-22 09:00:14,888 | DEBUG :  defining kr_event for sector 23
# 2019-01-22 09:00:14,990 | DEBUG :  defining kr_event for sector 24
# 2019-01-22 09:00:15,092 | DEBUG :  defining kr_event for sector 25
# 2019-01-22 09:00:15,189 | DEBUG :  defining kr_event for sector 26
# 2019-01-22 09:00:15,295 | DEBUG :  defining kr_event for sector 27
# 2019-01-22 09:00:15,411 | DEBUG :  defining kr_event for sector 28
# 2019-01-22 09:00:15,513 | DEBUG :  defining kr_event for sector 29
# 2019-01-22 09:00:15,615 | DEBUG :  defining kr_event for sector 30
# 2019-01-22 09:00:15,709 | DEBUG :  defining kr_event for sector 31
# 2019-01-22 09:00:15,811 | DEBUG :  defining kr_event for sector 32
# 2019-01-22 09:00:15,911 | DEBUG :  defining kr_event for sector 33
# 2019-01-22 09:00:16,014 | DEBUG :  defining kr_event for sector 34
# 2019-01-22 09:00:16,121 | DEBUG :  defining kr_event for sector 35
# 2019-01-22 09:00:16,226 | DEBUG :  defining kr_event for sector 36
# 2019-01-22 09:00:16,334 | DEBUG :  defining kr_event for sector 37
# 2019-01-22 09:00:16,439 | DEBUG :  defining kr_event for sector 38
# 2019-01-22 09:00:16,543 | DEBUG :  defining kr_event for sector 39
# 2019-01-22 09:00:16,646 | DEBUG :  defining kr_event for sector 40
# 2019-01-22 09:00:16,754 | DEBUG :  defining kr_event for sector 41
# 2019-01-22 09:00:16,874 | DEBUG :  defining kr_event for sector 42
# 2019-01-22 09:00:16,980 | DEBUG :  defining kr_event for sector 43
# 2019-01-22 09:00:17,088 | DEBUG :  defining kr_event for sector 44
# 2019-01-22 09:00:17,195 | DEBUG :  defining kr_event for sector 45
# 2019-01-22 09:00:17,296 | DEBUG :  defining kr_event for sector 46
# 2019-01-22 09:00:17,406 | DEBUG :  defining kr_event for sector 47
# 2019-01-22 09:00:17,522 | DEBUG :  defining kr_event for sector 48
# 2019-01-22 09:00:17,625 | DEBUG :  defining kr_event for sector 49
# 2019-01-22 09:00:17,752 | DEBUG :  defining kr_event for sector 50
# 2019-01-22 09:00:17,895 | DEBUG :  defining kr_event for sector 51
# 2019-01-22 09:00:18,000 | DEBUG :  defining kr_event for sector 52
# 2019-01-22 09:00:18,105 | DEBUG :  defining kr_event for sector 53
# 2019-01-22 09:00:18,214 | DEBUG :  defining kr_event for sector 54
# 2019-01-22 09:00:18,324 | DEBUG :  defining kr_event for sector 55
# 2019-01-22 09:00:18,430 | DEBUG :  defining kr_event for sector 56
# 2019-01-22 09:00:18,549 | DEBUG :  defining kr_event for sector 57
# 2019-01-22 09:00:18,661 | DEBUG :  defining kr_event for sector 58
# 2019-01-22 09:00:18,767 | DEBUG :  defining kr_event for sector 59
# 2019-01-22 09:00:18,874 | DEBUG :  defining kr_event for sector 60
# 2019-01-22 09:00:18,981 | DEBUG :  defining kr_event for sector 61
# 2019-01-22 09:00:19,100 | DEBUG :  defining kr_event for sector 62
# 2019-01-22 09:00:19,215 | DEBUG :  defining kr_event for sector 63
# 2019-01-22 09:00:19,317 | DEBUG :  defining kr_event for sector 64
# 2019-01-22 09:00:19,426 | DEBUG :  defining kr_event for sector 65
# 2019-01-22 09:00:19,527 | DEBUG :  defining kr_event for sector 66
# 2019-01-22 09:00:19,637 | DEBUG :  defining kr_event for sector 67
# 2019-01-22 09:00:19,741 | DEBUG :  defining kr_event for sector 68
# 2019-01-22 09:00:19,843 | DEBUG :  defining kr_event for sector 69
# 2019-01-22 09:00:19,954 | DEBUG :  defining kr_event for sector 70
# 2019-01-22 09:00:20,092 | DEBUG :  defining kr_event for sector 71
# 2019-01-22 09:00:20,229 | DEBUG :  defining kr_event for sector 72
# 2019-01-22 09:00:20,343 | DEBUG :  defining kr_event for sector 73
# 2019-01-22 09:00:20,442 | DEBUG :  defining kr_event for sector 74
# 2019-01-22 09:00:20,544 | DEBUG :  defining kr_event for sector 75
# 2019-01-22 09:00:20,642 | DEBUG :  defining kr_event for sector 76
# 2019-01-22 09:00:20,750 | DEBUG :  defining kr_event for sector 77
# 2019-01-22 09:00:20,855 | DEBUG :  defining kr_event for sector 78
# 2019-01-22 09:00:20,953 | DEBUG :  defining kr_event for sector 79
# 2019-01-22 09:00:21,050 | DEBUG :  defining kr_event for sector 80
# 2019-01-22 09:00:21,148 | DEBUG :  defining kr_event for sector 81
# 2019-01-22 09:00:21,247 | DEBUG :  defining kr_event for sector 82
# 2019-01-22 09:00:21,344 | DEBUG :  defining kr_event for sector 83
# 2019-01-22 09:00:21,440 | DEBUG :  defining kr_event for sector 84
# 2019-01-22 09:00:21,535 | DEBUG :  defining kr_event for sector 85
# 2019-01-22 09:00:21,628 | DEBUG :  defining kr_event for sector 86
# 2019-01-22 09:00:21,720 | DEBUG :  defining kr_event for sector 87
# 2019-01-22 09:00:21,810 | DEBUG :  defining kr_event for sector 88
# 2019-01-22 09:00:21,902 | DEBUG :  defining kr_event for sector 89
# 2019-01-22 09:00:21,992 | DEBUG :  defining kr_event for sector 90
# 2019-01-22 09:00:22,080 | DEBUG :  defining kr_event for sector 91
# 2019-01-22 09:00:22,161 | DEBUG :  defining kr_event for sector 92
# 2019-01-22 09:00:22,243 | DEBUG :  defining kr_event for sector 93
# 2019-01-22 09:00:22,319 | DEBUG :  defining kr_event for sector 94
# 2019-01-22 09:00:22,414 | DEBUG :  defining kr_event for sector 95
# 2019-01-22 09:00:22,494 | DEBUG :  defining kr_event for sector 96
# 2019-01-22 09:00:22,571 | DEBUG :  defining kr_event for sector 97
# 2019-01-22 09:00:22,651 | DEBUG :  defining kr_event for sector 98
# 2019-01-22 09:00:22,731 | DEBUG :  defining kr_event for sector 99
# 2019-01-22 09:00:22,814 | DEBUG :  RGES computed
#  KRES: t = 19.337944984436035

# %%
log.setLevel(logging.INFO)

# %%
neM = event_map(KRES)

# %%
ax = sns.heatmap(neM, square=True)

# %% [markdown]
# ## Fits in XY sectors

# %% [markdown]
# ## Maps

# %% [markdown]
# #### fit maps. The object returned is a Dict[int, List[FitParTS]] where
#
# ```
# @dataclass
# class FitParTS:             # Fit parameters Time Series
#     ts   : np.array          # contains the time series (integers expressing time differences)
#     e0   : np.array          # e0 fitted in time series
#     lt   : np.array
#     c2   : np.array
#     e0u  : np.array          # e0 error fitted in time series
#     ltu  : np.arra`
# ```

# %% [markdown]
# ### Single time bin

# %%
t0 = time.time()
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    fpmxy = fit_map_xy(selection_map = KRES,
                       event_map     = neM,
                       n_time_bins   = 1,
                       time_diffs    = DT,
                       nbins_z        = krNbins.Z, 
                       nbins_e        = krNbins.S2e, 
                       range_z        = z_range, 
                       range_e        = e_range,
                       energy        = 'S2e',
                       fit           = FitType.unbined,
                       n_min         = 100)

t1 = time.time()
print(f' fpmxy: t = {t1 -t0}')
# Out:
#  fpmxy: t = 1.0598738193511963

# %%
times = fpmxy[0][0].ts

# %%
times
# Out:
# array([20978.5])

# %% [markdown]
# #### Obtain time maps from fmap: The object returned is a SectorMapTS
# ```
# @dataclass
# class SectorMapTS:  # Map in chamber sector containing time series of pars
#     chi2  : Dict[int, List[np.array]]
#     e0    : Dict[int, List[np.array]]
#     lt    : Dict[int, List[np.array]]
#     e0u   : Dict[int, List[np.array]]
#     ltu   : Dict[int, List[np.array]]
# ```
# Here the dictionary is arranged for each of the relevant variables.

# %%
tsm = tsmap_from_fmap(fpmxy)

# %%
krNbins.Z
# Out:
# 15

# %%
plt.errorbar(times, tsm.lt[25][25], np.sqrt(tsm.lt[25][25]), fmt="p")
plt.errorbar(times, tsm.lt[25][21], np.sqrt(tsm.lt[25][21]), fmt="p")
plt.errorbar(times, tsm.lt[25][22], np.sqrt(tsm.lt[25][22]), fmt="p")
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
plt.errorbar(times, tsm.lt[30][10], np.sqrt(tsm.lt[6][10]), fmt="p")
plt.errorbar(times, tsm.lt[30][11], np.sqrt(tsm.lt[6][11]), fmt="p")
plt.errorbar(times, tsm.lt[30][12], np.sqrt(tsm.lt[6][12]), fmt="p")
# Out:
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# ### Obtain amap from tsm: The object returned is ASectorMap
# ```
# @dataclass
# class ASectorMap:  # Map in chamber sector containing average of pars
#     chi2  : DataFrame
#     e0    : DataFrame
#     lt    : DataFrame
#     e0u   : DataFrame
#     ltu   : DataFrame
# ```

# %% [markdown]
# #### There is a single time series (ts = 0)

# %%
am = amap_from_tsmap(tsm, 
                     ts = 0, 
                     range_e     = e_range,
                     range_chi2  = c2_range,
                     range_lt    = lt_range)

# %%
amap_average(am)
# Out:
# ASectorMap(chi2=nan, e0=nan, lt=nan, e0u=nan, ltu=nan, mapinfo=None)

# %% [markdown]
# #### Get rid of outlayers that distort mean and error

# %%
rmap = regularize_maps(am, erange=e_range, ltrange=lt_range)
# Out:
# 2019-01-22 09:00:25,949 | INFO :  set nans to average value of interval = 9500.0
# 2019-01-22 09:00:26,135 | INFO :  set nans to average value of interval = 3500.0

# %%
amap_average(rmap)
# Out:
# ASectorMap(chi2=nan, e0=nan, lt=nan, e0u=nan, ltu=nan, mapinfo=None)

# %%
asm = relative_errors(rmap)

# %%
amv = amap_average(asm)

# %% [markdown]
# #### Draw the maps using default colormap

# %%
draw_xy_maps(asm,
            e0lims  = e0_limits,
            ltlims  = lifetime_limits,
            eulims  = (0.0,  1),
            lulims  = (0, 5),
            figsize=(14,10),
            showPlots = False,
            plot_title = str(run_number))
plt.savefig(output_plots+'/lt_e0_xy_maps/lt_e0_xy_'+str(run_number)+'.png')
plt.savefig(summary_outputs+'maps.png')

# %%
asmAv = amap_replace_nan_by_mean(asm, amMean=amv)

# %%
amap_avg_list=amap_average(asmAv)

text_output = open(output_plots+'/text_outputs/outputs_'+str(run_number)+'.txt','w')

text_output.write('chi2='+str(amap_avg_list.chi2)+'\n')
text_output.write('e0='+str(amap_avg_list.e0)+'\n')
text_output.write('lt='+str(amap_avg_list.lt)+'\n')
text_output.write('e0u='+str(amap_avg_list.e0u)+'\n')
text_output.write('ltu='+str(amap_avg_list.ltu)+'\n')

mean = 0
num = 0

mean_low = 0
mean_high = 0

num_low = 0
num_high = 0

variance = 0
var_low = 0
var_high = 0

stdev = 0
stdev_low = 0
stdev_high = 0

zero_filled = asm.lt.fillna(0)
print(len(zero_filled))
for x in range(len(zero_filled)):
    ymax = len(zero_filled[x])
    for y in range(ymax):
        if (zero_filled[x][y] != 0):
            # get the mean
            mean += zero_filled[x][y]
            num += 1
            # get the means for low and high
            if y < ymax / 2:
                num_high += 1
                mean_high += zero_filled[x][y]
            else:
                num_low += 1
                mean_low += zero_filled[x][y]

mean /= num
mean_low /= num_low
mean_high /= num_high

for x in range(len(zero_filled)):
    ymax = len(zero_filled[x])
    for y in range(ymax):
        if (zero_filled[x][y] != 0):
            variance += (zero_filled[x][y] - mean)**2 / num
            if y < ymax / 2:
                var_high += (zero_filled[x][y] - mean_high)**2 / num_high
            else:
                var_low += (zero_filled[x][y] - mean_low)**2 / num_low
            
stdev = variance**0.5
stdev_low = var_low**0.5
stdev_high = var_high**0.5

mean_diff = (mean_high - mean_low) / mean


text_output.write('lt_mean_diff='+str(mean_diff)+'\n')
text_output.write('lt_mean_low='+str(mean_low)+'\n')
text_output.write('lt_mean_high='+str(mean_high)+'\n')
text_output.write('lt_stdev='+str(stdev)+'\n')
text_output.write('lt_stdev_low='+str(stdev_low)+'\n')
text_output.write('lt_stdev_high='+str(stdev_high)+'\n')

text_output.close()

amap_avg_list
print(asm.lt)
# Out:
# 100
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-71-c3b48c76dde4> in <module>
#      43                 mean_low += zero_filled[x][y]
#      44
# ---> 45 mean /= num
#      46 mean_low /= num_low
#      47 mean_high /= num_high
#
# ZeroDivisionError: division by zero

# %%
draw_xy_maps(asmAv,
            e0lims  = e0_limits,
            ltlims  = lifetime_limits,
            eulims  = (0.0,  1),
            lulims  = (0, 5),
            figsize=(14,10))

# %% [markdown]
# ### Save to file

# %%
print('The map info is:')
print(asmAv.mapinfo)
write_maps(asmAv, filename=fn.emap_file_name)

# %% [markdown]
# ### Read back

# %%
emaps = read_maps(filename=fn.emap_file_name)

# %%
draw_xy_maps(emaps,
            e0lims  = e0_limits,
            ltlims  = lifetime_limits,
            eulims  = (0.0,  1),
            lulims  = (0, 5),
            figsize=(14,10))

# %%
amap_average(emaps)

# %%
norm = amap_max(emaps)

# %%
norm

# %%
t0 = time.time()
E0 = e0_xy_correction(dst.S2e.values,
                      dst.X.values,
                      dst.Y.values,
                      E0M = emaps.e0 / norm.e0, 
                      xr  = krRanges.X,
                      yr  = krRanges.Y,
                      nx  = krNbins.X, 
                      ny  = krNbins.Y)


t1 = time.time()
print(f' e0 correction: t = {t1 -t0}')

# %%
t0 = time.time()
KRP = select_rphi_sectors(dst, DT, E0, dst.S2q, W)
t1 = time.time()
print(f' KRP: t = {t1 -t0}')

# %%
neM = event_map(KRP)

# %%
neM

# %%
neM[0]

# %%
fig = plt.figure(figsize=(14,8))
ax      = fig.add_subplot(2, 1, 1)
nevt = h2(dst.Z, dst.S2e, 50, 50, krRanges.Z, krRanges.S2e, 
           profile=True)
ax      = fig.add_subplot(2, 1, 2)
nevt = h2(dst.Z, E0, 50, 50, krRanges.Z, krRanges.S2e, 
           profile=True)

# %% [markdown]
# ### Now compute maps in rphi.

# %%
t0 = time.time()
fmap = fit_map_rphi(selection_map    = KRP,
                       event_map     = neM,
                       n_time_bins   = time_bins,
                       time_diffs     = DT,
                       nbins_z        = krNbins.Z, 
                       nbins_e        = krNbins.S2e, 
                       range_z        = z_range, 
                       range_e        = e_range,
                       energy         = 'S2e',
                       fit            = FitType.unbined,
                       n_min          = 100)
t1 = time.time()
print(f' fmap: t = {t1 -t0}')

# %%
tsm = tsmap_from_fmap(fmap)

# %%
erange=(0, 14500)
fig = plt.figure(figsize=(14,8))
for j in range(0,4):
    ax      = fig.add_subplot(2, 2, j+1)
    plt.ylim(erange)
    for i in neM.index:
        plt.errorbar(ts, tsm.e0[j][i], np.sqrt(tsm.e0[0][i]), fmt="p")

# %%
fig = plt.figure(figsize=(14,8))
ltrange=(0, 6000)
for j in range(0,4):
    plt.ylim(ltrange)
    ax      = fig.add_subplot(2, 2, j+1)
    for i in neM.index:
        plt.errorbar(ts, tsm.lt[j][i], np.sqrt(tsm.lt[0][i]), fmt="p")
#

# %%
t0 = time.time()
fmap2 = fit_map_rphi(selection_map    = KRP,
                       event_map     = neM,
                       n_time_bins   = time_bins,
                       time_diffs     = DT,
                       nbins_z        = krNbins.Z, 
                       nbins_e        = krNbins.S2e, 
                       range_z        = z_range, 
                       range_e        = e_range,
                       energy         = 'E',
                       fit            = FitType.unbined,
                       n_min          = 100)
t1 = time.time()
print(f' fmap: t = {t1 -t0}')

# %%
tsm2 = tsmap_from_fmap(fmap2)

# %%
erange=(8000, 14500)
fig = plt.figure(figsize=(14,8))
for j in range(0,4):
    ax      = fig.add_subplot(2, 2, j+1)
    plt.ylim(erange)
    for i in neM.index:
        plt.errorbar(ts, tsm2.e0[j][i], np.sqrt(tsm2.e0[0][i]), fmt="p")

# %%
fig = plt.figure(figsize=(14,8))
ltrange=(0, 6000)
for j in range(0,4):
    plt.ylim(ltrange)
    ax      = fig.add_subplot(2, 2, j+1)
    for i in neM.index:
        plt.errorbar(ts, tsm2.lt[j][i], np.sqrt(tsm2.lt[0][i]), fmt="p")

# %%
amts0 = amap_from_tsmap(tsm2, 
                     ts = 0, 
                     range_e     = e_range,
                     range_chi2  = c2_range,
                     range_lt    = lt_range)

# %%
avam = amap_average(amts0) 
avam

# %%
asm0 = relative_errors(amts0)

# %%
amap_average(asm0)

# %%
draw_rphi_maps(W, asm0,  
          e0lims  = e0_limits_rphi,
          ltlims  = lifetime_limits,
          eulims  = (0, 0.5),
          lulims  = (0,5),
          rmax=RMAX, 
          scale=0.5,
          alpha   = 1.0,  
          figsize=(14,10))

# %%
amts50 = amap_from_tsmap(tsm2, 
                     ts = 25, 
                     range_e     = e_range,
                     range_chi2  = c2_range,
                     range_lt    = lt_range)
asm50 = relative_errors(amts50)
amap_average(asm50) 

draw_rphi_maps(W, asm50,  
          e0lims  = e0_limits_rphi,
          ltlims  = lifetime_limits,
          eulims  = (0, 0.5),
          lulims  = (0,5),
          rmax=RMAX, 
          scale=0.5,
          alpha   = 1.0,  
          figsize=(14,10),
          showPlots = False,
          plot_title = str(run_number))
plt.savefig(output_plots+'/lt_e0_rphi_maps/lt_e0_rphi_'+str(run_number)+'.png')

# %% [markdown]
# ### Maps for the full time series

# %%
aMaps = []
EE    = []
LT    = []
TT    = []
t0 = time.time()
for i, tt in enumerate(ts):
    am = amap_from_tsmap(tsm2, 
                         ts = i, 
                         range_e     = (5000, 14500),
                         range_chi2  = (0,100),
                         range_lt    = (3000,5000))
    amv = amap_average(am) 
    asm = relative_errors(am)
    av = amap_replace_nan_by_mean(asm, amMean=amv)
    av0 = amap_average(av) 
    aMaps.append(av)
    EE.append(av0.e0)
    LT.append(av0.lt)
    TT.append(tt)
t1 = time.time()
print(f' t = {t1 -t0}')

# %%
plt.errorbar(TT, EE, 10, fmt="p")
plt.ylim(0,14500)

# %%
plt.errorbar(TT, LT, sqrt(LT), fmt="p")
plt.ylim(0,5000)
plt.savefig(summary_outputs+'AverageLT.png')

# %% [markdown]
# ### Write maps

# %%
fn.map_file_name_ts

# %%
write_maps_ts(aMaps, ts, filename=fn.map_file_name_ts)
time_write = time.time()

# %% [markdown]
# ### Read maps

# %%
tts, tsMaps = read_maps_ts(fn.map_file_name_ts)

# %%
kdst = kr_event(dst, DT, E0, dst.S2q)
fr = RMAX / NSECTORS

# %%
t0 = time.time()
kge =  e0_rphi_correction_ts(kdst, tts, tsMaps, fr, SPHI)     
t1 = time.time()
print(f' E0 correction: t = {t1 -t0}')

# %%
nevt = h2d(kge.Z, kge.E, 50, 50, krRanges.Z, krRanges.S2e, 
           pltLabels=PlotLabels(x='Z (mm)', y='S2e (pes)', title='S2 vs Z'),
           profile=True,
           figsize=(10,8))

# %%
t0 = time.time()
klt1 =  lt_rphi_correction_ts(kdst, tts, tsMaps, fr, SPHI)     
t1 = time.time()
print(f' LT correction: t = {t1 -t0}')

# %%
fig = plt.figure(figsize=(16,10))

ax      = fig.add_subplot(3, 1, 1)
nevt = h2(dst.Z, dst.S2e, 50, 50, krRanges.Z, krRanges.S2e, 
           profile=True)

ax      = fig.add_subplot(3, 1, 2)
nevt = h2(dst.Z, E0, 50, 50, krRanges.Z, krRanges.S2e, 
           profile=True)

ax      = fig.add_subplot(3, 1, 3)
nevt = h2(klt1.Z, klt1.E, 50, 50, krRanges.Z, krRanges.S2e, 
           profile=True)

plt.savefig(summary_outputs+'CorrectionLT.png')

# %%
t0 = time.time()
klt =  lt_rphi_correction_ts(kge, tts, tsMaps, fr, SPHI)     
t1 = time.time()
print(f' LT correction: t = {t1 -t0}')

# %%
nevt = h2d(klt.Z, klt.E, 50, 50, krRanges.Z, krRanges.S2e, 
           pltLabels=PlotLabels(x='Z (mm)', y='S2e (pes)', title='S2 vs Z'),
           profile=True,
           figsize=(10,8))

# %%
e_range = (11000, 14000)
fig = plt.figure(figsize=(14,8))
ax      = fig.add_subplot(1, 2, 1)

nevt = h2(klt1.Z, klt1.E, krNbins.Z, krNbins.S2e, krRanges.Z, e_range, profile=True)
plot_histo(PlotLabels(x='Z (mm)', y='E (pes)', title='E vs Z'), ax, legend=False)

ax      = fig.add_subplot(1, 2, 2)
(_)     = h1(klt1.E,  bins = 100, range =e_range, stats=True, lbl = 'E')
plot_histo(PlotLabels('E (pes)','Entries','E coor'), ax, legendloc='upper left')

# %%
fc = fit_energy(klt1.E, nbins=100, range=(12000, 14500))
plot_fit_energy(fc)
print_fit_energy(fc)

# %%
e_range = (11000, 14000)
fig = plt.figure(figsize=(14,8))
ax      = fig.add_subplot(1, 2, 1)

nevt = h2(klt.Z, klt.E, krNbins.Z, krNbins.S2e, krRanges.Z, e_range, profile=True)
plot_histo(PlotLabels(x='Z (mm)', y='E (pes)', title='E vs Z'), ax, legend=False)

ax      = fig.add_subplot(1, 2, 2)
(_)     = h1(klt.E,  bins = 100, range =e_range, stats=True, lbl = 'E')
plot_histo(PlotLabels('E (pes)','Entries','E coor'), ax, legendloc='upper left')

# %%
fc = fit_energy(klt.E, nbins=100, range=(12000, 14500))
plot_fit_energy(fc)
print_fit_energy(fc)

# %%
baseline = 12300
shift = 20
e1 = baseline - shift
e2 = baseline + shift
energy_time_profile(klt.T, klt.E, krNbins.T, krRanges.T, krTimes.timeStamps, 
                    erange=(12275, 12325),
                    figsize=(12,6))

# %%
energy_X_profile(klt.R, klt.E, xnbins = 100, xrange=(0,200), xlabel = 'R',
                 erange=(6500, 14500),  
                 figsize=(12,6))
plt.savefig(summary_outputs+'RProfile.png')

# %%
energy_X_profile(phirad_to_deg(klt.Phi), klt.E, xnbins = 100, xrange=(0,360), 
                 xlabel = 'Phi',
                 erange=(11000, 14500),  
                 figsize=(12,6))

# %%
energy_X_profile(klt.Z, klt.E, xnbins = 100, xrange=(0,500), xlabel = 'Z',
                 erange=(11000, 14500),   
                 figsize=(12,6))

# %%
T   =(klt.T - klt.T.min()) 
t, e, eu = fitf.profileX(T, klt.E, 100)
erange =(11000, 14500)
fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(1, 1, 1)
plt.errorbar(t, e, eu, fmt="kp", ms=7, lw=3)
plt.xlabel('t')
plt.ylabel('E (pes)')
plt.ylim(erange)

# %%
e_mu    = np.nanmean(klt.E)
print(e_mu)
e_std   = np.nanstd (klt.E)
print(e_std)

# %%
ET_correction = corrf.Correction((t,), e, eu,
                                 norm_strategy =  "const",
                                 norm_opts     = {"value": e_mu})
Ek  = klt.E * ET_correction(T).value

# %%
tc, ec, euc = fitf.profileX(T, Ek, 50)
fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(1, 1, 1)
plt.errorbar(tc, ec, euc, fmt="kp", ms=7, lw=3)
plt.xlabel('t')
plt.ylabel('Ek (pes)')
plt.ylim(erange)

# %% [markdown]
# ## Select events in region
# - r < 180
# - 10 < z < 550
# - 5000 < E < 14500

# %%
rrange = (0, 180)

ti = timeit(lt_xy_correction)
E = ti(E0, 
       dst.X.values, 
       dst.Y.values,
       dst.Z.values, 
       LTM = emaps.lt,
       xr  = krRanges.X,
       yr  = krRanges.Y,
       nx  = krNbins.X, 
       ny  = krNbins.Y)

sel = in_range(dst.R, *rrange) & in_range(dst.Z, *z_range) &  in_range(E, *e_range)
kse = kr_event(dst, DT, E, dst.S2q, sel)  # kse = krypton selected event

# %%
energy_X_profile(kse.R, kse.E, xnbins = 100, xrange=(0,200), xlabel = 'R',
                 erange=e_range,  
                 figsize=(12,6))
plt.savefig(summary_outputs+'RProfileC.png')

# %%
energy_X_profile(phirad_to_deg(kse.Phi), kse.E, xnbins = 100, xrange=(0,360), 
                 xlabel = 'Phi',
                 erange=e_range,  
                 figsize=(12,6))
plt.savefig(summary_outputs+'PhiProfile.png')

# %%
energy_X_profile(kse.Z, kse.E, xnbins = 100, xrange=z_range, xlabel = 'Z',
                 erange=e_range,   
                 figsize=(12,6))
plt.savefig(summary_outputs+'ZProfile.png')

# %%
energy_X_profile(kse.DT, kse.E, xnbins = 100, xrange=(kse.DT[0], kse.DT[-1]), xlabel = 'DT',
                 erange=e_range,   
                 figsize=(12,6))
plt.savefig(summary_outputs+'TProfile.png')

# %%
fig = plt.figure(figsize=(14,8))
ax      = fig.add_subplot(1, 2, 1)

(_)     = h1(klt.E,  bins = 100, range =(11000,14500), stats=True, lbl = 'E')
plot_histo(PlotLabels('E (pes)','Entries','E'), ax, legendloc='upper left')
ax      = fig.add_subplot(1, 2, 2)
(_)     = h1(Ek,  bins = 100, range =(11000,14500), stats=True, lbl = 'E')
plot_histo(PlotLabels('E (pes)','Entries','Ek'), ax, legendloc='upper left')

# %%
fc = fit_energy(Ek, nbins=50, range=(12000, 14500))
plot_fit_energy(fc)
print_fit_energy(fc)

# %%
Ri = (50, 100,150,160)
Zi = (50, 100,200,300,500)

FC, FCE = resolution_r_z(Ri, Zi, klt.R, klt.Z, Ek,
                    enbins = 50,
                    erange = (11e+3, 14500),
                    ixy = (5,4),
                    fdraw  = True,
                    fprint = False,
                    figsize = (18,10))
plt.savefig(summary_outputs+'ResoFit.png')

# %%
plot_resolution_r_z(Ri, Zi, FC, FCE)

# %%
Ri = (100,130,160)
Zi = (50, 100,200,300,400,500)

FC, FCE = resolution_r_z(Ri, Zi, klt.R, klt.Z, Ek,
                    enbins = 50,
                    erange = (11e+3, 14500),
                    ixy = (5,4),
                    fdraw  = True,
                    fprint = False,
                    figsize = (18,10))

# %%
plot_resolution_r_z(Ri, Zi, FC, FCE, showPlots = False, plot_title=str(run_number))
plt.savefig(output_plots+'/res_vs_rz/res_vs_rz_'+str(run_number)+'.png')
plt.savefig(summary_outputs+'ResoVsZR.png')

# %%
dt_write = time_write - t_start
dt_plots = time.time() - time_write
print('Time to write =', round(dt_write/60.0,1), 'm')
print('Time to show plots =', round(dt_plots/60.0,1), 'm')
