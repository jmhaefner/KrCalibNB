# %% [markdown]
# # Krypton Lifetime maps

# %% [markdown]
# ### Author:  JJGC

# %% [markdown]
# ### Software: KrCalib : https://github.com/nextic/KrCalib/

# %%
# %load_ext autoreload
# %autoreload 2
import os
import sys
import time
import warnings
import datetime 
print("Last updated on ", time.asctime())
# Out:
# Last updated on  Sat Dec  1 18:02:54 2018

# %% [markdown]
# ### Logger

# %%
import logging


logging.basicConfig(format='%(asctime)s | %(levelname)s : %(message)s',
                     level=logging.INFO, stream=sys.stdout)

logging.info('Hello world!')
# Out:
# 2018-12-01 18:02:54,825 | INFO : Hello world!

# %% [markdown]
# ### Input files

# %%
from krcal.core.kr_types import KrFileName

run_number = <RUN_NUMBER>
num_files = <NUM_FILES>

if num_files > 7729:
    num_xy_bins = 100
else:
    num_xy_bins = 50

# run_number = 6340 # for testing only
t_start = time.time()

lifetime_limits = (2350, 5150)
e0_limits = (7000, 14000)
e0_limits_rphi = (12000, 14000)

input_path  = f"$IC_DATA/dst"
output_path = f"$IC_DATA/ldst"
output_plots = f"$IC_DATA/plots"
output_plots = os.path.expandvars(f"{output_plots}/")
summary_outputs = "/Users/jmhaefner/Development/KryptonCalibration/KrCalibNB_JMH/KrCalibNB/doc/img/r"+str(run_number)+"/"
map_path    = f"$IC_DATA/maps"

# Find the name of the correct input dst

dst_directory = os.path.expandvars(f"{input_path}/")
dirlist = os.listdir(dst_directory)
dst_file = ""
for file_name in dirlist:
    try:
        check_number = file_name
        check_number = check_number[check_number.find('_')+1:]
        check_number = check_number[:check_number.find('_')]
        if check_number == str(run_number):
            print('Found the dst:',file_name)
            dst_file = file_name
    except:
        pass

if dst_file == "":
    raise ValueError("Unable to find appropriate dst for run "+str(run_number))

input_file_names  = [ dst_file ]

    
time_bins = 25
output_file_name  = ' '
map_file_name     = 'kr_maps_xy_'+str(run_number)+'.h5'
map_file_name_ts  = f'kr_maps_rphi_5_8_ts_{time_bins}_'+str(run_number)+'.h5'
emap_file_name    = 'kr_emap_xy_'+str(num_xy_bins)+'_'+str(num_xy_bins)+'_r_'+str(run_number)+'.h5'

krfn = KrFileName(input_file_names,
                  output_file_name,
                  map_file_name,
                  map_file_name_ts,
                  emap_file_name)
# Out:
# Found the dst: dst_6340_trigger1_0000_7678.h5

# %% [markdown]
# ### Notebook configuration

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

from matplotlib.patches import Circle, Wedge, Polygon
from matplotlib.collections import PatchCollection

plt.rcParams["figure.figsize"] = 10, 8
plt.rcParams["font.size"     ] = 14

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib
import tables            as tb
import random
import glob
import warnings
sns.set()

# %%
from  invisible_cities.io.dst_io              import load_dsts
from  invisible_cities.core .core_functions   import in_range
import invisible_cities.reco.corrections      as corrf

# %%
from krcal.core.io_functions       import kdst_write
from krcal.core.io_functions       import filenames_from_list
from krcal.core.io_functions       import write_maps
from krcal.core.io_functions       import read_maps
from krcal.core.io_functions       import write_maps_ts
from krcal.core.io_functions       import read_maps_ts

# %%
from krcal.core.histo_functions    import h1, h1d, h2, h2d, plot_histo

# %%
from krcal.core.core_functions      import time_delta_from_time
from krcal.core.core_functions      import phirad_to_deg
from krcal.core.core_functions      import timeit
from krcal.core.core_functions      import NN
from krcal.core                     import fit_functions_ic as fitf

# %%
from krcal.core.plt_functions  import plot_sector
from krcal.core.plt_functions  import plot_sectors

# %%
from krcal.core.stat_functions      import mean_and_std

# %%
from krcal.core.analysis_functions  import kr_ranges_and_bins
from krcal.core.analysis_functions  import fiducial_volumes
from krcal.core.analysis_functions  import fid_eff
from krcal.core.analysis_functions  import select_rphi_sectors
from krcal.core.analysis_functions  import select_xy_sectors
from krcal.core.analysis_functions  import event_map

from krcal.core.analysis_functions  import kr_event_selection
from krcal.core.analysis_functions  import kr_event

# %%
from krcal.core.fit_lt_functions    import fit_lifetime
from krcal.core.fit_lt_functions    import time_fcs
from krcal.core.fit_lt_functions    import fit_fcs_in_rphi_sectors
from krcal.core.fit_lt_functions    import fit_fcs_in_xy_bin
from krcal.core.fit_lt_functions    import fit_map_rphi
from krcal.core.fit_lt_functions    import fit_map_xy
from krcal.core.fit_lt_functions    import get_time_series

# %%
from krcal.core.fit_lt_histograms   import histo_fit_sectors
from krcal.core.fit_lt_histograms   import print_fit_sectors_pars
from krcal.core.fit_lt_histograms   import plot_fit_sectors
from krcal.core.fit_lt_histograms   import plot_fit_xy
from krcal.core.fit_lt_histograms   import plot_time_fcs
from krcal.core.fit_lt_histograms   import plot_fit_lifetime_and_chi2
from krcal.core.fit_lt_histograms   import print_fit_lifetime

# %%
from krcal.core.fit_energy_functions    import fit_energy
from krcal.core.fit_energy_functions    import plot_fit_energy
from krcal.core.fit_energy_functions    import print_fit_energy
from krcal.core.fit_energy_functions    import resolution_r_z
from krcal.core.fit_energy_functions    import plot_resolution_r_z

# %%
from krcal.core.kr_types import PlotLabels, KrEvent, ASectorMap
from krcal.core.kr_types import FitType, KrSector, MapType
from krcal.core.kr_types import KrFileName

# %%
from krcal.core.rphi_maps_functions   import draw_rphi_maps
from krcal.core.rphi_maps_functions   import draw_rphi_map
from krcal.core.rphi_maps_functions   import draw_rphi_maps_ts
from krcal.core.rphi_maps_functions   import draw_wedges
from krcal.core.rphi_maps_functions   import define_rphi_sectors
from krcal.core.rphi_maps_functions   import rphi_sector_map_def

# %%
from krcal.core.map_functions   import tsmap_from_fmap
from krcal.core.map_functions   import amap_from_tsmap
from krcal.core.map_functions   import relative_errors
from krcal.core.map_functions   import amap_valid_mask
from krcal.core.map_functions   import amap_valid_fraction
from krcal.core.map_functions   import amap_average
from krcal.core.map_functions   import amap_max
from krcal.core.map_functions   import amap_min
from krcal.core.map_functions   import amap_replace_nan_by_mean
from krcal.core.map_functions   import amap_replace_nan_by_zero
from krcal.core.map_functions   import regularize_maps
from krcal.core.map_functions   import get_maps_from_tsmap
from krcal.core.map_functions   import map_average

# %%
from krcal.core.xy_maps_functions   import draw_xy_maps
from krcal.core.xy_maps_functions   import draw_xy_map
from krcal.core.xy_maps_functions   import draw_xy_maps_ts

# %%
from krcal.core.s1s2_functions  import energy_time_profile
from krcal.core.s1s2_functions  import energy_X_profile

# %%
from krcal.core.correction_functions import e0_rphi_correction
from krcal.core.correction_functions import e0_xy_correction
from krcal.core.correction_functions import lt_xy_correction
from krcal.core.correction_functions import e0_xy_correction_ts
from krcal.core.correction_functions import lt_xy_correction_ts
from krcal.core.correction_functions import lt_rphi_correction
from krcal.core.correction_functions import lt_rphi_correction_ts
from krcal.core.correction_functions import e0_rphi_correction_ts

# %%
from numpy import pi, sqrt

# %%
from typing      import List, Tuple, Dict, Sequence, Iterable

# %%
from ipywidgets import interact, interactive, fixed
from IPython.display import display

# %% [markdown]
# ### Logger
#
#
# - CRITICAL
# - ERROR
# - WARNING
# - INFO
# - DEBUG

# %%
log = logging.getLogger()

# %% [markdown]
# ### Input/output

# %%
fn =filenames_from_list(krfn, input_path, output_path, map_path)

# %%
t0 = time.time()
dst           = load_dsts(fn.input_file_names, "DST", "Events")
t1 = time.time()
print(f'Read in file time: t = {t1 -t0}')
# Out:
# Read in file time: t = 2.736032009124756

# %%
unique_events = ~dst.event.duplicated()
number_of_evts_full = np.count_nonzero(unique_events)

print(f"Total number of events: {len(dst)}")
# Out:
# Total number of events: 706864

# %%
dst.columns
# Out:
# Index(['index', 'event', 'time', 's1_peak', 's2_peak', 'nS1', 'nS2', 'S1w',
#        'S1h', 'S1e', 'S1t', 'S2w', 'S2h', 'S2e', 'S2q', 'S2t', 'Nsipm', 'DT',
#        'Z', 'Zrms', 'X', 'Y', 'R', 'Phi', 'Xrms', 'Yrms'],
#       dtype='object')

# %% [markdown]
# ### Time differences in seconds

# %%
dst_time = dst.sort_values('time')
T       = dst_time.time.values
DT      = time_delta_from_time(T)

# %% [markdown]
# ### Ranges and binning

# %%
RMAX      = 200
RCORE     = 100
s1e_range = (3, 25)
s2e_range = (2000, 14000)
s2q_range = (200, 800)

xy_range  = (-RMAX,  RMAX)
z_range   = (10,  550)
e_range = (5000, 14000)
lt_range = (1000, 7000)
c2_range = (0,5)

krTimes, krRanges, krNbins, krBins = kr_ranges_and_bins(dst,
                                                        xxrange   = xy_range,
                                                        yrange    = xy_range,
                                                        zrange    = z_range,
                                                        s2erange  = s2e_range,
                                                        s1erange  = s1e_range,
                                                        s2qrange  = s2q_range,
                                                        xnbins    = num_xy_bins,
                                                        ynbins    = num_xy_bins,
                                                        znbins    = 15,
                                                        s2enbins  = 25,
                                                        s1enbins  = 10,
                                                        s2qnbins  = 25,
                                                        tpsamples = 3600) # tsamples in seconds

# %%
dst = dst[in_range(dst.R, 0, RMAX)]

# %%
dst_time = dst.sort_values('time')
T       = dst_time.time.values
DT      = time_delta_from_time(T)
plt.plot(DT)
plt.show()
plt.plot(T)
plt.show()

# %%
kge = kr_event(dst, DT, dst.S2e, dst.S2q)

# %%
fig = plt.figure(figsize=(10,6))
ax      = fig.add_subplot(1, 1, 1)
(_)    = h1(kge.DT, bins=500, range = (kge.DT[0], kge.DT[-1]), color='red', stats=False, lbl='pre-sel')

# %% [markdown]
# ### Time

# %%
plt.plot(krTimes.timeStamps)

# %% [markdown]
# ### Event distribution

# %%
nevt = h2d(dst.X, dst.Y, krNbins.X, krNbins.Y, krRanges.X, krRanges.Y, 
           pltLabels=PlotLabels(x='X (mm)', y='Y (mm)', title='X vs Y '+str(run_number)),
           profile=False,
           figsize=(10,8))
plt.savefig(output_plots+'/EventDists/EventDist_'+str(run_number)+'.png')

# %% [markdown]
# ## Time series

# %%
log.setLevel(logging.INFO)

# %% [markdown]
# ### Divide dst in 100 time series

# %%
time_bins = 25
t0 = time.time()

ts, masks = get_time_series(time_bins, (DT[0],DT[-1]), kge)
t1 = time.time()
print(f' get_time_series: t = {t1 -t0}')
# Out:
#  get_time_series: t = 0.04560399055480957

# %% [markdown]
# ### Fit lifetime full detector

# %%
t0 = time.time()
fps = time_fcs(ts, masks, kge, 
               nbins_z = 15,
               nbins_e = 25,
               range_z = (10, 550),
               range_e = (7000, 14000),
               energy  = 'S2e',
               fit     = FitType.profile) # lifetime fit parameter time series
t1 = time.time()
print(f' time_fcs: t = {t1 -t0}')
# Out:
#  time_fcs: t = 0.3135800361633301

# %%
plot_time_fcs(fps,
              range_chi2  = (0,20),
              range_e0    = (10000,10400),
              range_lt    = lt_range,
              figsize     = (12,6))

# %% [markdown]
# ## Lifetime in RPhi

# %%
NSECTORS =5  # number of sectors in R. Each sector then is 200 / 5 = 40 cm.
SPHI     =45 # size of the phi pie-slice in degrees, thus 10 slices in phi.
#NSECTORS =4  # number of sectors in R. Each sector then is 200 / 5 = 40 cm.
#SPHI     =45 # size of the phi pie-slice in degrees, thus 10 slices in phi.

# %%
rpsmd = rphi_sector_map_def(nSectors=NSECTORS, rmax=RMAX, sphi=SPHI)

# %%
W = define_rphi_sectors(rpsmd)

# %%
draw_wedges(W,  rmax = RMAX, 
            scale= 0.49, figsize=(10,8), alpha=1.0,
            cr =range(NSECTORS))

# %%
t0 = time.time()
KSRP = select_rphi_sectors(dst, DT, dst.S2e, dst.S2q, W)
t1 = time.time()
print(f' KRES: t = {t1 -t0}')
# Out:
#  KRES: t = 1.3564550876617432

# %%
neM = event_map(KSRP)

# %%
neM
# Out:
#       0      1      2      3      4
# 0  3593  11634  19741  28550  32047
# 1  3582  10805  19035  27520  30738
# 2  3704  10142  16673  24682  27974
# 3  3534  10539  16972  23546  26592
# 4  3705  10569  18361  23325  26364
# 5  3841  11305  18774  26400  24744
# 6  4008  12170  20183  28499  27229
# 7  3745  11168  20596  28233  29347

# %%
ax = sns.heatmap(neM, square=True)

# %% [markdown]
# ### four phi sectors: upper half (left-right), lower half (left-right) of chamber

# %% [markdown]
# ### R < 40 mm

# %%
erange = (0,14500)
ltrange = (0, 7000)

# %%
for sector in range(NSECTORS):
    fps = fit_fcs_in_rphi_sectors(sector = sector,
                              selection_map = KSRP,
                              event_map     = neM,
                              n_time_bins   = time_bins,
                              time_diffs    = DT,
                              nbins_z       = 25,
                              nbins_e       = 50,
                              range_z       =(50, 550),
                              range_e       = (5000, 14500),
                              energy        = 'S2e',
                              fit           = FitType.unbined,
                              n_min         = 100)
    plot_fit_sectors(fps,  range_e0 =erange, range_lt=ltrange)
    plt.savefig(summary_outputs+'R_phi_lt'+str(sector+1)+'.png')

# %% [markdown]
# ### Lifetime patterns:
#
# - Oscillatory pattern in time with a swing of 1 ms!
# - Lifetime changes also as a function of Phi, with differences that increase as R increases.
# - R > 160 cm data shows very high and very variable lifetime, with a spread of several ms.

# %% [markdown]
# ### Strategy
#
# - Try to correct geometrical effects first. Fine grained geometrical map with a single time bin.
# - Study time dependence later

# %% [markdown]
# ## Divide chamber in sectors of XY

# %%
log.setLevel(logging.DEBUG)

# %%
t0 = time.time()
print(len(dst))
print(len(DT))
KRES = select_xy_sectors(dst, DT, dst.S2e.values, dst.S2q.values, krBins.X, krBins.Y)
t1 = time.time()
print(f' KRES: t = {t1 -t0}')
# Out:
# 704169
# 704169
# 2018-12-01 18:03:20,974 | DEBUG :  function: select_xy_sectors
# 2018-12-01 18:03:20,975 | DEBUG :  calling selection_mask
# 2018-12-01 18:03:20,976 | DEBUG : computing selection mask for sector 0
# 2018-12-01 18:03:21,073 | DEBUG : computing selection mask for sector 1
# 2018-12-01 18:03:21,180 | DEBUG : computing selection mask for sector 2
# 2018-12-01 18:03:21,272 | DEBUG : computing selection mask for sector 3
# 2018-12-01 18:03:21,371 | DEBUG : computing selection mask for sector 4
# 2018-12-01 18:03:21,482 | DEBUG : computing selection mask for sector 5
# 2018-12-01 18:03:21,600 | DEBUG : computing selection mask for sector 6
# 2018-12-01 18:03:21,701 | DEBUG : computing selection mask for sector 7
# 2018-12-01 18:03:21,806 | DEBUG : computing selection mask for sector 8
# 2018-12-01 18:03:21,901 | DEBUG : computing selection mask for sector 9
# 2018-12-01 18:03:21,994 | DEBUG : computing selection mask for sector 10
# 2018-12-01 18:03:22,107 | DEBUG : computing selection mask for sector 11
# 2018-12-01 18:03:22,238 | DEBUG : computing selection mask for sector 12
# 2018-12-01 18:03:22,363 | DEBUG : computing selection mask for sector 13
# 2018-12-01 18:03:22,481 | DEBUG : computing selection mask for sector 14
# 2018-12-01 18:03:22,621 | DEBUG : computing selection mask for sector 15
# 2018-12-01 18:03:22,727 | DEBUG : computing selection mask for sector 16
# 2018-12-01 18:03:22,878 | DEBUG : computing selection mask for sector 17
# 2018-12-01 18:03:22,986 | DEBUG : computing selection mask for sector 18
# 2018-12-01 18:03:23,094 | DEBUG : computing selection mask for sector 19
# 2018-12-01 18:03:23,209 | DEBUG : computing selection mask for sector 20
# 2018-12-01 18:03:23,392 | DEBUG : computing selection mask for sector 21
# 2018-12-01 18:03:23,518 | DEBUG : computing selection mask for sector 22
# 2018-12-01 18:03:23,631 | DEBUG : computing selection mask for sector 23
# 2018-12-01 18:03:23,740 | DEBUG : computing selection mask for sector 24
# 2018-12-01 18:03:23,845 | DEBUG : computing selection mask for sector 25
# 2018-12-01 18:03:23,958 | DEBUG : computing selection mask for sector 26
# 2018-12-01 18:03:24,065 | DEBUG : computing selection mask for sector 27
# 2018-12-01 18:03:24,177 | DEBUG : computing selection mask for sector 28
# 2018-12-01 18:03:24,283 | DEBUG : computing selection mask for sector 29
# 2018-12-01 18:03:24,393 | DEBUG : computing selection mask for sector 30
# 2018-12-01 18:03:24,502 | DEBUG : computing selection mask for sector 31
# 2018-12-01 18:03:24,606 | DEBUG : computing selection mask for sector 32
# 2018-12-01 18:03:24,717 | DEBUG : computing selection mask for sector 33
# 2018-12-01 18:03:24,823 | DEBUG : computing selection mask for sector 34
# 2018-12-01 18:03:24,933 | DEBUG : computing selection mask for sector 35
# 2018-12-01 18:03:25,042 | DEBUG : computing selection mask for sector 36
# 2018-12-01 18:03:25,180 | DEBUG : computing selection mask for sector 37
# 2018-12-01 18:03:25,389 | DEBUG : computing selection mask for sector 38
# 2018-12-01 18:03:25,556 | DEBUG : computing selection mask for sector 39
# 2018-12-01 18:03:25,695 | DEBUG : computing selection mask for sector 40
# 2018-12-01 18:03:25,984 | DEBUG : computing selection mask for sector 41
# 2018-12-01 18:03:26,296 | DEBUG : computing selection mask for sector 42
# 2018-12-01 18:03:26,474 | DEBUG : computing selection mask for sector 43
# 2018-12-01 18:03:26,660 | DEBUG : computing selection mask for sector 44
# 2018-12-01 18:03:26,853 | DEBUG : computing selection mask for sector 45
# 2018-12-01 18:03:27,012 | DEBUG : computing selection mask for sector 46
# 2018-12-01 18:03:27,157 | DEBUG : computing selection mask for sector 47
# 2018-12-01 18:03:27,302 | DEBUG : computing selection mask for sector 48
# 2018-12-01 18:03:27,428 | DEBUG : computing selection mask for sector 49
# 2018-12-01 18:03:27,550 | DEBUG :  selection mask computed, filling selections
# 2018-12-01 18:03:27,551 | DEBUG :  defining kr_event for sector 0
# 2018-12-01 18:03:27,747 | DEBUG :  defining kr_event for sector 1
# 2018-12-01 18:03:27,897 | DEBUG :  defining kr_event for sector 2
# 2018-12-01 18:03:28,031 | DEBUG :  defining kr_event for sector 3
# 2018-12-01 18:03:28,177 | DEBUG :  defining kr_event for sector 4
# 2018-12-01 18:03:28,315 | DEBUG :  defining kr_event for sector 5
# 2018-12-01 18:03:28,471 | DEBUG :  defining kr_event for sector 6
# 2018-12-01 18:03:28,618 | DEBUG :  defining kr_event for sector 7
# 2018-12-01 18:03:28,825 | DEBUG :  defining kr_event for sector 8
# 2018-12-01 18:03:29,049 | DEBUG :  defining kr_event for sector 9
# 2018-12-01 18:03:29,268 | DEBUG :  defining kr_event for sector 10
# 2018-12-01 18:03:29,525 | DEBUG :  defining kr_event for sector 11
# 2018-12-01 18:03:29,693 | DEBUG :  defining kr_event for sector 12
# 2018-12-01 18:03:29,899 | DEBUG :  defining kr_event for sector 13
# 2018-12-01 18:03:30,201 | DEBUG :  defining kr_event for sector 14
# 2018-12-01 18:03:30,465 | DEBUG :  defining kr_event for sector 15
# 2018-12-01 18:03:30,719 | DEBUG :  defining kr_event for sector 16
# 2018-12-01 18:03:30,966 | DEBUG :  defining kr_event for sector 17
# 2018-12-01 18:03:31,230 | DEBUG :  defining kr_event for sector 18
# 2018-12-01 18:03:31,475 | DEBUG :  defining kr_event for sector 19
# 2018-12-01 18:03:31,656 | DEBUG :  defining kr_event for sector 20
# 2018-12-01 18:03:31,885 | DEBUG :  defining kr_event for sector 21
# 2018-12-01 18:03:32,066 | DEBUG :  defining kr_event for sector 22
# 2018-12-01 18:03:32,356 | DEBUG :  defining kr_event for sector 23
# 2018-12-01 18:03:32,635 | DEBUG :  defining kr_event for sector 24
# 2018-12-01 18:03:32,910 | DEBUG :  defining kr_event for sector 25
# 2018-12-01 18:03:33,133 | DEBUG :  defining kr_event for sector 26
# 2018-12-01 18:03:33,323 | DEBUG :  defining kr_event for sector 27
# 2018-12-01 18:03:33,539 | DEBUG :  defining kr_event for sector 28
# 2018-12-01 18:03:33,857 | DEBUG :  defining kr_event for sector 29
# 2018-12-01 18:03:34,202 | DEBUG :  defining kr_event for sector 30
# 2018-12-01 18:03:34,409 | DEBUG :  defining kr_event for sector 31
# 2018-12-01 18:03:34,587 | DEBUG :  defining kr_event for sector 32
# 2018-12-01 18:03:34,829 | DEBUG :  defining kr_event for sector 33
# 2018-12-01 18:03:35,105 | DEBUG :  defining kr_event for sector 34
# 2018-12-01 18:03:35,370 | DEBUG :  defining kr_event for sector 35
# 2018-12-01 18:03:35,630 | DEBUG :  defining kr_event for sector 36
# 2018-12-01 18:03:35,910 | DEBUG :  defining kr_event for sector 37
# 2018-12-01 18:03:36,110 | DEBUG :  defining kr_event for sector 38
# 2018-12-01 18:03:36,294 | DEBUG :  defining kr_event for sector 39
# 2018-12-01 18:03:36,456 | DEBUG :  defining kr_event for sector 40
# 2018-12-01 18:03:36,668 | DEBUG :  defining kr_event for sector 41
# 2018-12-01 18:03:36,955 | DEBUG :  defining kr_event for sector 42
# 2018-12-01 18:03:37,200 | DEBUG :  defining kr_event for sector 43
# 2018-12-01 18:03:37,447 | DEBUG :  defining kr_event for sector 44
# 2018-12-01 18:03:37,652 | DEBUG :  defining kr_event for sector 45
# 2018-12-01 18:03:37,811 | DEBUG :  defining kr_event for sector 46
# 2018-12-01 18:03:37,954 | DEBUG :  defining kr_event for sector 47
# 2018-12-01 18:03:38,171 | DEBUG :  defining kr_event for sector 48
# 2018-12-01 18:03:38,410 | DEBUG :  defining kr_event for sector 49
# 2018-12-01 18:03:38,839 | DEBUG :  RGES computed
#  KRES: t = 18.306105136871338

# %%
log.setLevel(logging.INFO)

# %%
neM = event_map(KRES)

# %%
ax = sns.heatmap(neM, square=True)

# %% [markdown]
# ## Fits in XY sectors

# %% [markdown]
# ## Maps

# %% [markdown]
# #### fit maps. The object returned is a Dict[int, List[FitParTS]] where
#
# ```
# @dataclass
# class FitParTS:             # Fit parameters Time Series
#     ts   : np.array          # contains the time series (integers expressing time differences)
#     e0   : np.array          # e0 fitted in time series
#     lt   : np.array
#     c2   : np.array
#     e0u  : np.array          # e0 error fitted in time series
#     ltu  : np.arra`
# ```

# %% [markdown]
# ### Single time bin

# %%
t0 = time.time()
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    fpmxy = fit_map_xy(selection_map = KRES,
                       event_map     = neM,
                       n_time_bins   = 1,
                       time_diffs    = DT,
                       nbins_z        = krNbins.Z, 
                       nbins_e        = krNbins.S2e, 
                       range_z        = z_range, 
                       range_e        = e_range,
                       energy        = 'S2e',
                       fit           = FitType.unbined,
                       n_min         = 100)

t1 = time.time()
print(f' fpmxy: t = {t1 -t0}')
# Out:
#  fpmxy: t = 14.42052412033081

# %%
times = fpmxy[0][0].ts

# %%
times
# Out:
# array([30533.])

# %% [markdown]
# #### Obtain time maps from fmap: The object returned is a SectorMapTS
# ```
# @dataclass
# class SectorMapTS:  # Map in chamber sector containing time series of pars
#     chi2  : Dict[int, List[np.array]]
#     e0    : Dict[int, List[np.array]]
#     lt    : Dict[int, List[np.array]]
#     e0u   : Dict[int, List[np.array]]
#     ltu   : Dict[int, List[np.array]]
# ```
# Here the dictionary is arranged for each of the relevant variables.

# %%
tsm = tsmap_from_fmap(fpmxy)

# %%
plt.errorbar(times, tsm.lt[25][25], np.sqrt(tsm.lt[25][25]), fmt="p")
plt.errorbar(times, tsm.lt[25][21], np.sqrt(tsm.lt[25][21]), fmt="p")
plt.errorbar(times, tsm.lt[25][22], np.sqrt(tsm.lt[25][22]), fmt="p")
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
plt.errorbar(times, tsm.lt[30][10], np.sqrt(tsm.lt[6][10]), fmt="p")
plt.errorbar(times, tsm.lt[30][11], np.sqrt(tsm.lt[6][11]), fmt="p")
plt.errorbar(times, tsm.lt[30][12], np.sqrt(tsm.lt[6][12]), fmt="p")
# Out:
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# ### Obtain amap from tsm: The object returned is ASectorMap
# ```
# @dataclass
# class ASectorMap:  # Map in chamber sector containing average of pars
#     chi2  : DataFrame
#     e0    : DataFrame
#     lt    : DataFrame
#     e0u   : DataFrame
#     ltu   : DataFrame
# ```

# %% [markdown]
# #### There is a single time series (ts = 0)

# %%
am = amap_from_tsmap(tsm, 
                     ts = 0, 
                     range_e     = e_range,
                     range_chi2  = c2_range,
                     range_lt    = lt_range)

# %%
amap_average(am)
# Out:
# ASectorMap(chi2=0.9899427869356374, e0=9989.735976742828, lt=2631.1972048619523, e0u=29.675390612939232, ltu=67.85331028192964, mapinfo=None)

# %% [markdown]
# #### Get rid of outlayers that distort mean and error

# %%
rmap = regularize_maps(am, erange=e_range, ltrange=lt_range)
# Out:
# 2018-12-01 18:03:55,641 | INFO :  set nans to average value of interval = 9500.0
# 2018-12-01 18:03:55,752 | INFO :  set nans to average value of interval = 3500.0

# %%
amap_average(rmap)
# Out:
# ASectorMap(chi2=0.9899427869356374, e0=9989.735976742828, lt=2631.1972048619523, e0u=29.675390612939232, ltu=67.85331028192964, mapinfo=None)

# %%
asm = relative_errors(rmap)

# %%
amv = amap_average(asm)

# %% [markdown]
# #### Draw the maps using default colormap

# %%
draw_xy_maps(asm,
            e0lims  = e0_limits,
            ltlims  = lifetime_limits,
            eulims  = (0.0,  1),
            lulims  = (0, 5),
            figsize=(14,10),
            showPlots = False,
            plot_title = str(run_number))
plt.savefig(output_plots+'/lt_e0_xy_maps/lt_e0_xy_'+str(run_number)+'.png')
plt.savefig(summary_outputs+'maps.png')

# %%
asmAv = amap_replace_nan_by_mean(asm, amMean=amv)

# %%
amap_avg_list=amap_average(asmAv)

text_output = open(output_plots+'/text_outputs/outputs_'+str(run_number)+'.txt','w')

text_output.write('chi2='+str(amap_avg_list.chi2)+'\n')
text_output.write('e0='+str(amap_avg_list.e0)+'\n')
text_output.write('lt='+str(amap_avg_list.lt)+'\n')
text_output.write('e0u='+str(amap_avg_list.e0u)+'\n')
text_output.write('ltu='+str(amap_avg_list.ltu)+'\n')

mean = 0
num = 0

mean_low = 0
mean_high = 0

num_low = 0
num_high = 0

variance = 0
var_low = 0
var_high = 0

stdev = 0
stdev_low = 0
stdev_high = 0

zero_filled = asm.lt.fillna(0)
print(len(zero_filled))
for x in range(len(zero_filled)):
    ymax = len(zero_filled[x])
    for y in range(ymax):
        if (zero_filled[x][y] != 0):
            # get the mean
            mean += zero_filled[x][y]
            num += 1
            # get the means for low and high
            if y < ymax / 2:
                num_high += 1
                mean_high += zero_filled[x][y]
            else:
                num_low += 1
                mean_low += zero_filled[x][y]

mean /= num
mean_low /= num_low
mean_high /= num_high

for x in range(len(zero_filled)):
    ymax = len(zero_filled[x])
    for y in range(ymax):
        if (zero_filled[x][y] != 0):
            variance += (zero_filled[x][y] - mean)**2 / num
            if y < ymax / 2:
                var_high += (zero_filled[x][y] - mean_high)**2 / num_high
            else:
                var_low += (zero_filled[x][y] - mean_low)**2 / num_low
            
stdev = variance**0.5
stdev_low = var_low**0.5
stdev_high = var_high**0.5

mean_diff = (mean_high - mean_low) / mean


text_output.write('lt_mean_diff='+str(mean_diff)+'\n')
text_output.write('lt_mean_low='+str(mean_low)+'\n')
text_output.write('lt_mean_high='+str(mean_high)+'\n')
text_output.write('lt_stdev='+str(stdev)+'\n')
text_output.write('lt_stdev_low='+str(stdev_low)+'\n')
text_output.write('lt_stdev_high='+str(stdev_high)+'\n')

text_output.close()

amap_avg_list
print(asm.lt)
# Out:
# 50
#              0            1            2            3            4   \
# 0           NaN          NaN          NaN          NaN          NaN
# 1           NaN          NaN          NaN          NaN          NaN
# 2           NaN          NaN          NaN          NaN          NaN
# 3           NaN          NaN          NaN          NaN          NaN
# 4           NaN          NaN          NaN          NaN          NaN
# 5           NaN          NaN          NaN          NaN          NaN
# 6           NaN          NaN          NaN          NaN          NaN
# 7           NaN          NaN          NaN          NaN          NaN
# 8           NaN          NaN          NaN          NaN          NaN
# 9           NaN          NaN          NaN          NaN          NaN
# 10          NaN          NaN          NaN          NaN          NaN
# 11          NaN          NaN          NaN          NaN  2948.999184
# 12          NaN          NaN          NaN  2323.480554  2223.739407
# 13          NaN          NaN          NaN  2404.226208  2440.420622
# 14          NaN          NaN  2300.281567  2452.256973  2476.940210
# 15          NaN          NaN  2372.294084  2509.291378  2572.698067
# 16          NaN  2106.272985  2491.949651  2569.053832  2777.668196
# 17          NaN  2429.194804  2326.369119  2651.429852  2767.854832
# 18          NaN  2286.049797  2403.095499  2509.254082  2816.495626
# 19          NaN  2396.494729  2563.867582  2663.226800  2681.560856
# 20  2219.363471  2427.059985  2535.878488  2622.982808  2704.080597
# 21  2446.488587  2197.167070  2465.087606  2599.472379  2637.856040
# 22  2358.014351  2375.377244  2474.994722  2441.054834  2703.226920
# 23  2570.336812  2451.931832  2580.428730  2651.196401  2659.980955
# 24  2257.761433  2314.282853  2399.196692  2543.125758  2622.351526
# 25  2548.784659  2204.003666  2660.893874  2564.921966  2662.506346
# 26  2394.530545  2426.406785  2445.122148  2608.103528  2717.445569
# 27  2710.149287  2312.329741  2524.546593  2617.358684  2667.313915
# 28  2741.247063  2244.149177  2364.232518  2514.663320  2684.160257
# 29          NaN  2433.575545  2513.716529  2580.043606  2606.963856
# 30          NaN  2714.942379  2533.990610  2593.998280  2679.749398
# 31          NaN  2626.494056  2339.631112  2438.600472  2649.103644
# 44          NaN          NaN          NaN          NaN          NaN
# 45          NaN          NaN          NaN          NaN          NaN
# 46          NaN          NaN          NaN          NaN          NaN
# 47          NaN          NaN          NaN          NaN          NaN
# 48          NaN          NaN          NaN          NaN          NaN
# 49          NaN          NaN          NaN          NaN          NaN
#
#        ...                40           41           42           43  \
# 0      ...               NaN          NaN          NaN          NaN
# 1      ...               NaN          NaN          NaN          NaN
# 2      ...               NaN          NaN          NaN          NaN
# 3      ...               NaN          NaN          NaN          NaN
# 4      ...               NaN          NaN          NaN          NaN
# 5      ...       2077.172975          NaN          NaN          NaN
# 6      ...       2505.497594  2302.706724          NaN          NaN
# 7      ...       2490.968103  2226.005178          NaN          NaN
# 8      ...       2456.404231  2481.851653  2326.626432          NaN
# 9      ...       2616.590576  2647.954273  2371.924575  2391.819789
# 10     ...       2689.785427  2546.125855  2428.571796  2263.076274
# 11     ...       2742.258296  2700.299572  2637.486420  2539.969099
# 12     ...       2794.153853  2670.646420  2540.877313  2510.008368
# 13     ...       2705.192397  2813.078035  2705.901842  2677.506841
# 14     ...       2717.783859  2684.125206  2670.902712  2704.585882
# 15     ...       2717.126959  2653.519542  2605.545288  2687.129815
# 16     ...       2829.312997  2633.620652  2626.736580  2671.145140
# 17     ...       2763.629036  2726.014076  2691.008774  2678.150014
# 18     ...       2762.719711  2824.345366  2685.746504  2753.851693
# 19     ...       2936.374567  2805.457664  2762.079663  2598.592844
# 20     ...       2703.156665  2815.663098  2704.167072  2714.710510
# 21     ...       2662.501569  2706.436429  2786.295786  2703.053637
# 22     ...       2681.071287  2737.312838  2770.848894  2659.800884
# 23     ...       2669.628275  2618.970118  2667.924986  2668.481689
# 24     ...       2747.929997  2787.347389  2815.904457  2566.817824
# 25     ...       2840.170378  2821.904492  2622.036545  2633.963008
# 26     ...       2776.599455  2736.262815  2584.485890  2759.493879
# 27     ...       2735.234777  2748.196818  2630.383227  2794.080900
# 28     ...       2730.136748  2648.227987  2685.872617  2672.965753
# 29     ...       2777.625170  2725.207635  2816.053057  2822.736014
# 30     ...       2724.689204  2768.943330  2842.026021  2788.456103
# 31     ...       2732.689936  2733.286985  2601.915091  2714.029523
# 32     ...       2672.197546  2660.821485  2578.375214  2626.849435
# 33     ...       2585.055823  2681.916018  2584.574752  2494.070799
# 34     ...       2663.319974  2753.603120  2680.938133  2623.322456
# 35     ...       2610.606824  2719.935171  2534.061109  2579.092594
# 36     ...       2666.141497  2590.074462  2612.281010  2511.527292
# 37     ...       2501.979976  2538.615409  2497.101729  2551.368107
# 38     ...       2540.706949  2630.914275  2488.797371  2511.322235
# 39     ...       2553.697282  2536.512374  2500.630800  2477.129853
# 40     ...       2591.609541  2542.531767  2478.927159  2883.589557
# 41     ...       2355.954544  2456.677267  2550.080782          NaN
# 42     ...       2429.056831  2379.065166          NaN          NaN
# 43     ...       2341.227678          NaN          NaN          NaN
# 44     ...               NaN          NaN          NaN          NaN
# 45     ...               NaN          NaN          NaN          NaN
# 46     ...               NaN          NaN          NaN          NaN
# 47     ...               NaN          NaN          NaN          NaN
# 48     ...               NaN          NaN          NaN          NaN
# 49     ...               NaN          NaN          NaN          NaN
#
#              44           45           46           47           48  \
# 0           NaN          NaN          NaN          NaN          NaN
# 1           NaN          NaN          NaN          NaN          NaN
# 2           NaN          NaN          NaN          NaN          NaN
# 3           NaN          NaN          NaN          NaN          NaN
# 4           NaN          NaN          NaN          NaN          NaN
# 5           NaN          NaN          NaN          NaN          NaN
# 6           NaN          NaN          NaN          NaN          NaN
# 7           NaN          NaN          NaN          NaN          NaN
# 8           NaN          NaN          NaN          NaN          NaN
# 9           NaN          NaN          NaN          NaN          NaN
# 


# %%
draw_rphi_maps(W, asm0,  
          e0lims  = e0_limits_rphi,
          ltlims  = lifetime_limits,
          eulims  = (0, 0.5),
          lulims  = (0,5),
          rmax=RMAX, 
          scale=0.5,
          alpha   = 1.0,  
          figsize=(14,10))

# %%
amts50 = amap_from_tsmap(tsm2, 
                     ts = 25, 
                     range_e     = e_range,
                     range_chi2  = c2_range,
                     range_lt    = lt_range)
asm50 = relative_errors(amts50)
amap_average(asm50) 

draw_rphi_maps(W, asm50,  
          e0lims  = e0_limits_rphi,
          ltlims  = lifetime_limits,
          eulims  = (0, 0.5),
          lulims  = (0,5),
          rmax=RMAX, 
          scale=0.5,
          alpha   = 1.0,  
          figsize=(14,10),
          showPlots = False,
          plot_title = str(run_number))
plt.savefig(output_plots+'/lt_e0_rphi_maps/lt_e0_rphi_'+str(run_number)+'.png')

# %% [markdown]
# ### Maps for the full time series

# %%
aMaps = []
EE    = []
LT    = []
TT    = []
t0 = time.time()
for i, tt in enumerate(ts):
    am = amap_from_tsmap(tsm2, 
                         ts = i, 
                         range_e     = (5000, 14500),
                         range_chi2  = (0,100),
                         range_lt    = lt_range)
    amv = amap_average(am) 
    asm = relative_errors(am)
    av = amap_replace_nan_by_mean(asm, amMean=amv)
    av0 = amap_average(av) 
    aMaps.append(av)
    EE.append(av0.e0)
    LT.append(av0.lt)
    TT.append(tt)
t1 = time.time()
print(f' t = {t1 -t0}')
# Out:
#  t = 0.28565478324890137

# %%
plt.errorbar(TT, EE, 10, fmt="p")
plt.ylim(0,14500)
# Out:
# (0, 13500)

# %%
plt.errorbar(TT, LT, sqrt(LT), fmt="p")
plt.ylim(lt_range)
plt.savefig(summary_outputs+'AverageLT.png')
# Out:
# (0, 5000)

# %% [markdown]
# ### Write maps

# %%
fn.map_file_name_ts
# Out:
# '/Volumes/NEXT_data/IC_Data//maps/kr_maps_rphi_5_8_ts_25_6340.h5'

# %%
write_maps_ts(aMaps, ts, filename=fn.map_file_name_ts)
time_write = time.time()

# %% [markdown]
# ### Read maps

# %%
tts, tsMaps = read_maps_ts(fn.map_file_name_ts)

# %%
kdst = kr_event(dst, DT, E0, dst.S2q)
fr = RMAX / NSECTORS

# %%
t0 = time.time()
kge =  e0_rphi_correction_ts(kdst, tts, tsMaps, fr, SPHI)     
t1 = time.time()
print(f' E0 correction: t = {t1 -t0}')
# Out:
#  E0 correction: t = 10.272066116333008

# %%
nevt = h2d(kge.Z, kge.E, 50, 50, krRanges.Z, krRanges.S2e, 
           pltLabels=PlotLabels(x='Z (mm)', y='S2e (pes)', title='S2 vs Z'),
           profile=True,
           figsize=(10,8))

# %%
t0 = time.time()
klt1 =  lt_rphi_correction_ts(kdst, tts, tsMaps, fr, SPHI)     
t1 = time.time()
print(f' LT correction: t = {t1 -t0}')
# Out:
#  LT correction: t = 10.19194483757019

# %%
fig = plt.figure(figsize=(16,10))

ax      = fig.add_subplot(3, 1, 1)
nevt = h2(dst.Z, dst.S2e, 50, 50, krRanges.Z, krRanges.S2e, 
           profile=True)

ax      = fig.add_subplot(3, 1, 2)
nevt = h2(dst.Z, E0, 50, 50, krRanges.Z, krRanges.S2e, 
           profile=True)

ax      = fig.add_subplot(3, 1, 3)
nevt = h2(klt1.Z, klt1.E, 50, 50, krRanges.Z, krRanges.S2e, 
           profile=True)

plt.savefig(summary_outputs+'CorrectionLT.png')

# %%
t0 = time.time()
klt =  lt_rphi_correction_ts(kge, tts, tsMaps, fr, SPHI)     
t1 = time.time()
print(f' LT correction: t = {t1 -t0}')
# Out:
#  LT correction: t = 10.29116702079773

# %%
nevt = h2d(klt.Z, klt.E, 50, 50, krRanges.Z, krRanges.S2e, 
           pltLabels=PlotLabels(x='Z (mm)', y='S2e (pes)', title='S2 vs Z'),
           profile=True,
           figsize=(10,8))

# %%
e_range = (11000, 14000)
fig = plt.figure(figsize=(14,8))
ax      = fig.add_subplot(1, 2, 1)

nevt = h2(klt1.Z, klt1.E, krNbins.Z, krNbins.S2e, krRanges.Z, e_range, profile=True)
plot_histo(PlotLabels(x='Z (mm)', y='E (pes)', title='E vs Z'), ax, legend=False)

ax      = fig.add_subplot(1, 2, 2)
(_)     = h1(klt1.E,  bins = 100, range =e_range, stats=True, lbl = 'E')
plot_histo(PlotLabels('E (pes)','Entries','E coor'), ax, legendloc='upper left')

# %%
fc = fit_energy(klt1.E, nbins=100, range=(12000, 14500))
plot_fit_energy(fc)
print_fit_energy(fc)
# Out:
#   Fit was valid = True
#  Emu       = 12602.048832257426 +-0.37078514373324034
#  E sigma   = 279.6354393374922 +-0.31060605667850066
#  chi2    = 3.148832255560312
#  sigma E/E (FWHM)     (%) =5.214574956740518
#  sigma E/E (FWHM) Qbb (%) =0.6734725571658617

# %%
e_range = (11000, 14000)
fig = plt.figure(figsize=(14,8))
ax      = fig.add_subplot(1, 2, 1)

nevt = h2(klt.Z, klt.E, krNbins.Z, krNbins.S2e, krRanges.Z, e_range, profile=True)
plot_histo(PlotLabels(x='Z (mm)', y='E (pes)', title='E vs Z'), ax, legend=False)

ax      = fig.add_subplot(1, 2, 2)
(_)     = h1(klt.E,  bins = 100, range =e_range, stats=True, lbl = 'E')
plot_histo(PlotLabels('E (pes)','Entries','E coor'), ax, legendloc='upper left')

# %%
fc = fit_energy(klt.E, nbins=100, range=(12000, 14500))
plot_fit_energy(fc)
print_fit_energy(fc)
# Out:
#   Fit was valid = True
#  Emu       = 12699.598859217287 +-0.3716271854819424
#  E sigma   = 290.3620038497321 +-0.3113862123695275
#  chi2    = 3.9463100456800357
#  sigma E/E (FWHM)     (%) =5.373009940007867
#  sigma E/E (FWHM) Qbb (%) =0.6939347452081808

# %%
baseline = 12300
shift = 20
e1 = baseline - shift
e2 = baseline + shift
energy_time_profile(klt.T, klt.E, krNbins.T, krRanges.T, krTimes.timeStamps, 
                    erange=(12275, 12325),
                    figsize=(12,6))

# %%
energy_X_profile(klt.R, klt.E, xnbins = num_xy_bins, xrange=(0,200), xlabel = 'R',
                 erange=(6500, 14500),  
                 figsize=(12,6))
plt.savefig(summary_outputs+'RProfile.png')

# %%
energy_X_profile(phirad_to_deg(klt.Phi), klt.E, xnbins = num_xy_bins, xrange=(0,360), 
                 xlabel = 'Phi',
                 erange=(11000, 14500),  
                 figsize=(12,6))

# %%
energy_X_profile(klt.Z, klt.E, xnbins = num_xy_bins, xrange=(0,500), xlabel = 'Z',
                 erange=(11000, 14500),   
                 figsize=(12,6))

# %%
T   =(klt.T - klt.T.min()) 
t, e, eu = fitf.profileX(T, klt.E, 100)
erange =(11000, 14500)
fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(1, 1, 1)
plt.errorbar(t, e, eu, fmt="kp", ms=7, lw=3)
plt.xlabel('t')
plt.ylabel('E (pes)')
plt.ylim(erange)
# Out:
# (11000, 13500)

# %%
e_mu    = np.nanmean(klt.E)
print(e_mu)
e_std   = np.nanstd (klt.E)
print(e_std)
# Out:
# 12681.846180958148
# 410.828100231038

# %%
ET_correction = corrf.Correction((t,), e, eu,
                                 norm_strategy =  "const",
                                 norm_opts     = {"value": e_mu})
Ek  = klt.E * ET_correction(T).value

# %%
tc, ec, euc = fitf.profileX(T, Ek, 50)
fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(1, 1, 1)
plt.errorbar(tc, ec, euc, fmt="kp", ms=7, lw=3)
plt.xlabel('t')
plt.ylabel('Ek (pes)')
plt.ylim(erange)
# Out:
# (11000, 13500)

# %% [markdown]
# ## Select events in region
# - r < 180
# - 10 < z < 550
# - 5000 < E < 14500

# %%
rrange = (0, 180)

ti = timeit(lt_xy_correction)
E = ti(E0, 
       dst.X.values, 
       dst.Y.values,
       dst.Z.values, 
       LTM = emaps.lt,
       xr  = krRanges.X,
       yr  = krRanges.Y,
       nx  = krNbins.X, 
       ny  = krNbins.Y)

sel = in_range(dst.R, *rrange) & in_range(dst.Z, *z_range) &  in_range(E, *e_range)
kse = kr_event(dst, DT, E, dst.S2q, sel)  # kse = krypton selected event

# %%
energy_X_profile(kse.R, kse.E, xnbins = num_xy_bins, xrange=(0,200), xlabel = 'R',
                 erange=e_range,  
                 figsize=(12,6))
plt.savefig(summary_outputs+'RProfileC.png')

# %%
energy_X_profile(phirad_to_deg(kse.Phi), kse.E, xnbins = num_xy_bins, xrange=(0,360), 
                 xlabel = 'Phi',
                 erange=e_range,  
                 figsize=(12,6))
plt.savefig(summary_outputs+'PhiProfile.png')

# %%
energy_X_profile(kse.Z, kse.E, xnbins = num_xy_bins, xrange=z_range, xlabel = 'Z',
                 erange=e_range,   
                 figsize=(12,6))
plt.savefig(summary_outputs+'ZProfile.png')

# %%
energy_X_profile(kse.DT, kse.E, xnbins = num_xy_bins, xrange=(kse.DT[0], kse.DT[-1]), xlabel = 'DT',
                 erange=e_range,   
                 figsize=(12,6))
plt.savefig(summary_outputs+'TProfile.png')

# %%
fig = plt.figure(figsize=(14,8))
ax      = fig.add_subplot(1, 2, 1)

(_)     = h1(klt.E,  bins = 100, range =(11000,14500), stats=True, lbl = 'E')
plot_histo(PlotLabels('E (pes)','Entries','E'), ax, legendloc='upper left')
ax      = fig.add_subplot(1, 2, 2)
(_)     = h1(Ek,  bins = 100, range =(11000,14500), stats=True, lbl = 'E')
plot_histo(PlotLabels('E (pes)','Entries','Ek'), ax, legendloc='upper left')

# %%
fc = fit_energy(Ek, nbins=50, range=(12000, 14500))
plot_fit_energy(fc)
print_fit_energy(fc)
# Out:
#   Fit was valid = True
#  Emu       = 12699.946168316572 +-0.36062588933200973
#  E sigma   = 283.4473098712109 +-0.2997306682476749
#  chi2    = 6.281973867052657
#  sigma E/E (FWHM)     (%) =5.244913398602539
#  sigma E/E (FWHM) Qbb (%) =0.6773908262847728

# %%
Ri = (50, 100,150,160)
Zi = (50, 100,200,300,500)

FC, FCE = resolution_r_z(Ri, Zi, klt.R, klt.Z, Ek,
                    enbins = 50,
                    erange = (11e+3, 14500),
                    ixy = (5,4),
                    fdraw  = True,
                    fprint = False,
                    figsize = (18,10))
plt.savefig(summary_outputs+'ResoFit.png')

# %%
plot_resolution_r_z(Ri, Zi, FC, FCE)

# %%
Ri = (100,130,160)
Zi = (50, 100,200,300,400,500)

FC, FCE = resolution_r_z(Ri, Zi, klt.R, klt.Z, Ek,
                    enbins = 50,
                    erange = (11e+3, 14500),
                    ixy = (5,4),
                    fdraw  = True,
                    fprint = False,
                    figsize = (18,10))

# %%
plot_resolution_r_z(Ri, Zi, FC, FCE, showPlots = False, plot_title=str(run_number))
plt.savefig(output_plots+'/res_vs_rz/res_vs_rz_'+str(run_number)+'.png')
plt.savefig(summary_outputs+'ResoVsZR.png')
# Out:
# /Users/jmhaefner/miniconda/envs/IC-3.6-2018-11-07/lib/python3.6/site-packages/matplotlib/figure.py:98: MatplotlibDeprecationWarning:
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   "Adding an axes using the same arguments as a previous axes "

# %%
dt_write = time_write - t_start
dt_plots = time.time() - time_write
print('Time to write =', round(dt_write/60.0,1), 'm')
print('Time to show plots =', round(dt_plots/60.0,1), 'm')
# Out:
# Time to write = 1.7 m
# Time to show plots = 0.9 m
